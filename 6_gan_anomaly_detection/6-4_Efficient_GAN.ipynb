# %% [markdown]
# # 6.4 Efficient GANの作成
#
# - 本ファイルでは、Efficient GANのネットワークを実装し、学習をします。

# %% [markdown]
# # 6.4 学習目標
#
# 1.	Efficient GANを実装し、手書き数字画像で異常検知が生成できる

# %% [markdown]
# # 事前準備
# 書籍の指示に従い、本章で使用するデータを用意します

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Linear(z_dim, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.Linear(1024, 7*7*128),
            nn.BatchNorm1d(7*7*128),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=128, out_channels=64,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(in_channels=64, out_channels=1,
                               kernel_size=4, stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)

        # 転置畳み込み層に入れるためにテンソルの形を整形
        out = out.view(z.shape[0], 128, 7, 7)
        out = self.layer3(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20)
G.train()

# 入力する乱数
# バッチノーマライゼーションがあるのでミニバッチ数は2以上
input_z = torch.randn(2, 20)

# 偽画像を出力
fake_images = G(input_z)  # torch.Size([2, 1, 28, 28])
img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20):
        super(Discriminator, self).__init__()

        # 画像側の入力処理
        self.x_layer1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.x_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        # 乱数側の入力処理
        self.z_layer1 = nn.Linear(z_dim, 512)

        # 最後の判定
        self.last1 = nn.Sequential(
            nn.Linear(3648, 1024),
            nn.LeakyReLU(0.1, inplace=True))

        self.last2 = nn.Linear(1024, 1)

    def forward(self, x, z):

        # 画像側の入力処理
        x_out = self.x_layer1(x)
        x_out = self.x_layer2(x_out)

        # 乱数側の入力処理
        z = z.view(z.shape[0], -1)
        z_out = self.z_layer1(z)

        # x_outとz_outを結合し、全結合層で判定
        x_out = x_out.view(-1, 64 * 7 * 7)
        out = torch.cat([x_out, z_out], dim=1)
        out = self.last1(out)

        feature = out  # 最後にチャネルを1つに集約する手前の情報
        feature = feature.view(feature.size()[0], -1)  # 2次元に変換

        out = self.last2(out)

        return out, feature

# %%
# 動作確認
D = Discriminator(z_dim=20)

# 偽画像を生成
input_z = torch.randn(2, 20)
fake_images = G(input_z)

# 偽画像をDに入力
d_out, _ = D(fake_images, input_z)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[0.4976],
#         [0.4939]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # Encoderの実装
#
# 画像をzに変換する

# %%
class Encoder(nn.Module):

    def __init__(self, z_dim=20):
        super(Encoder, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3,
                      stride=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True))

        # ここまでで画像のサイズは7×7になっている
        self.last = nn.Linear(128 * 7 * 7, z_dim)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)

        # FCに入れるためにテンソルの形を整形
        out = out.view(-1, 128 * 7 * 7)
        out = self.last(out)

        return out

# %%
# 動作確認
E = Encoder(z_dim=20)

# 入力する画像データ
x = fake_images  # fake_imagesは上のGで作成したもの

# 画像からzをEncode
z = E(x)

print(z.shape)
print(z)
# Out:
# torch.Size([2, 20])
# tensor([[-0.2117, -0.3586,  0.1473, -0.1527, -0.0279, -0.2314, -0.0856, -0.2432,
#           0.0342,  0.1805,  0.0172, -0.0165,  0.1778,  0.3555,  0.2951, -0.3447,
#          -0.3518, -0.1325, -0.0354, -0.2111],
#         [-0.1011,  0.2350,  0.0888, -0.2578,  0.1728,  0.3983,  0.1063, -0.1835,
#          -0.0881,  0.1863,  0.2127, -0.1049,  0.0425,  0.0202,  0.2042, -0.2098,
#           0.1348, -0.1092, -0.3779, -0.2373]], grad_fn=<AddmmBackward>)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イタレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# # 学習させる

# %%
# モデルを学習させる関数を作成


def train_model(G, D, E, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    lr_ge = 0.0001
    lr_d = 0.0001/4
    beta1, beta2 = 0.5, 0.999
    g_optimizer = torch.optim.Adam(G.parameters(), lr_ge, [beta1, beta2])
    e_optimizer = torch.optim.Adam(E.parameters(), lr_ge, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), lr_d, [beta1, beta2])

    # 誤差関数を定義
    # BCEWithLogitsLossは入力にシグモイド（logit）をかけてから、
    # バイナリークロスエントロピーを計算
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    E.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    E.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イタレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_e_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # ミニバッチサイズの1もしくは0のラベル役のテンソルを作成
            # 正解ラベルと偽ラベルを作成
            # epochの最後のイタレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # 真の画像を判定　
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            # 誤差を計算
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. Encoderの学習
            # --------------------
            # 真の画像のzを推定
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            # 誤差を計算
            e_loss = criterion(d_out_real.view(-1), label_fake)

            # バックプロパゲーション
            e_optimizer.zero_grad()
            e_loss.backward()
            e_optimizer.step()

            # --------------------
            # 4. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            epoch_e_loss += e_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f} ||Epoch_E_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size, epoch_e_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    print("総イタレーション回数:", iteration)

    return G, D, E

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # ConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        # 全結合層Linearの初期化
        m.bias.data.fill_(0)


# 初期化の実施
G.apply(weights_init)
E.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# 学習・検証を実行する
# 15分ほどかかる
num_epochs = 1500
G_update, D_update, E_update = train_model(
    G, D, E, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/1500
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.1489 ||Epoch_G_Loss:0.0780 ||Epoch_E_Loss:0.0769
# timer:  0.6927 sec.
# -------------
# Epoch 1/1500
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.1447 ||Epoch_G_Loss:0.0805 ||Epoch_E_Loss:0.0789
# timer:  0.4335 sec.
# -------------
# Epoch 2/1500
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.1404 ||Epoch_G_Loss:0.0829 ||Epoch_E_Loss:0.0816
# timer:  0.4295 sec.
# -------------
# Epoch 3/1500
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.1358 ||Epoch_G_Loss:0.0848 ||Epoch_E_Loss:0.0851
# timer:  0.4302 sec.
# -------------
# Epoch 4/1500
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.1317 ||Epoch_G_Loss:0.0865 ||Epoch_E_Loss:0.0888
# timer:  0.4308 sec.
# -------------
# Epoch 5/1500
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.1279 ||Epoch_G_Loss:0.0880 ||Epoch_E_Loss:0.0919
# timer:  0.4306 sec.
# -------------
# Epoch 6/1500
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.1249 ||Epoch_G_Loss:0.0890 ||Epoch_E_Loss:0.0942
# timer:  0.4316 sec.
# -------------
# Epoch 7/1500
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.1217 ||Epoch_G_Loss:0.0910 ||Epoch_E_Loss:0.0977
# timer:  0.4295 sec.
# -------------
# Epoch 8/1500
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.1176 ||Epoch_G_Loss:0.0923 ||Epoch_E_Loss:0.1034
# timer:  0.4307 sec.
# -------------
# Epoch 9/1500
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.1134 ||Epoch_G_Loss:0.0946 ||Epoch_E_Loss:0.1066
# timer:  0.4311 sec.
# -------------
# Epoch 10/1500
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.1130 ||Epoch_G_Loss:0.0972 ||Epoch_E_Loss:0.1058
# timer:  0.4305 sec.
# -------------
# Epoch 11/1500
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.1090 ||Epoch_G_Loss:0.0988 ||Epoch_E_Loss:0.1108
# timer:  0.4315 sec.
# -------------
# Epoch 12/1500
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.1015 ||Epoch_G_Loss:0.1025 ||Epoch_E_Loss:0.1223
# timer:  0.4314 sec.
# -------------
# Epoch 13/1500
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.0985 ||Epoch_G_Loss:0.1054 ||Epoch_E_Loss:0.1227
# timer:  0.4296 sec.
# -------------
# Epoch 14/1500
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0952 ||Epoch_G_Loss:0.1082 ||Epoch_E_Loss:0.1236
# timer:  0.4323 sec.
# -------------
# Epoch 15/1500
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0877 ||Epoch_G_Loss:0.1152 ||Epoch_E_Loss:0.1353
# timer:  0.4335 sec.
# -------------
# Epoch 16/1500
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0794 ||Epoch_G_Loss:0.1217 ||Epoch_E_Loss:0.1444
# timer:  0.4319 sec.
# -------------
# Epoch 17/1500
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0785 ||Epoch_G_Loss:0.1286 ||Epoch_E_Loss:0.1413
# timer:  0.4325 sec.
# -------------
# Epoch 18/1500
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0726 ||Epoch_G_Loss:0.1367 ||Epoch_E_Loss:0.1507
# timer:  0.4333 sec.
# -------------
# Epoch 19/1500
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0632 ||Epoch_G_Loss:0.1482 ||Epoch_E_Loss:0.1712
# timer:  0.4332 sec.
# -------------
# Epoch 20/1500
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.0582 ||Epoch_G_Loss:0.1548 ||Epoch_E_Loss:0.1771
# timer:  0.4314 sec.
# -------------
# Epoch 21/1500
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0555 ||Epoch_G_Loss:0.1630 ||Epoch_E_Loss:0.1781
# timer:  0.4300 sec.
# -------------
# Epoch 22/1500
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0493 ||Epoch_G_Loss:0.1753 ||Epoch_E_Loss:0.1901
# timer:  0.4307 sec.
# -------------
# Epoch 23/1500
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.0438 ||Epoch_G_Loss:0.1845 ||Epoch_E_Loss:0.2043
# timer:  0.4309 sec.
# -------------
# Epoch 24/1500
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.0413 ||Epoch_G_Loss:0.1928 ||Epoch_E_Loss:0.2064
# timer:  0.4311 sec.
# -------------
# Epoch 25/1500
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.0395 ||Epoch_G_Loss:0.2034 ||Epoch_E_Loss:0.2100
# timer:  0.4307 sec.
# -------------
# Epoch 26/1500
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.0330 ||Epoch_G_Loss:0.2150 ||Epoch_E_Loss:0.2375
# timer:  0.4295 sec.
# -------------
# Epoch 27/1500
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0280 ||Epoch_G_Loss:0.2288 ||Epoch_E_Loss:0.2592
# timer:  0.4306 sec.
# -------------
# Epoch 28/1500
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.0270 ||Epoch_G_Loss:0.2371 ||Epoch_E_Loss:0.2566
# timer:  0.4320 sec.
# -------------
# Epoch 29/1500
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.0277 ||Epoch_G_Loss:0.2461 ||Epoch_E_Loss:0.2469
# timer:  0.4306 sec.
# -------------
# Epoch 30/1500
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0257 ||Epoch_G_Loss:0.2534 ||Epoch_E_Loss:0.2592
# timer:  0.4330 sec.
# -------------
# Epoch 31/1500
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.0234 ||Epoch_G_Loss:0.2610 ||Epoch_E_Loss:0.2731
# timer:  0.4288 sec.
# -------------
# Epoch 32/1500
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.0224 ||Epoch_G_Loss:0.2648 ||Epoch_E_Loss:0.2750
# timer:  0.4308 sec.
# -------------
# Epoch 33/1500
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.0215 ||Epoch_G_Loss:0.2724 ||Epoch_E_Loss:0.2844
# timer:  0.4304 sec.
# -------------
# Epoch 34/1500
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.0186 ||Epoch_G_Loss:0.2818 ||Epoch_E_Loss:0.3083
# timer:  0.4292 sec.
# -------------
# Epoch 35/1500
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.0164 ||Epoch_G_Loss:0.2929 ||Epoch_E_Loss:0.3238
# timer:  0.4300 sec.
# -------------
# Epoch 36/1500
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.0154 ||Epoch_G_Loss:0.2999 ||Epoch_E_Loss:0.3257
# timer:  0.4276 sec.
# -------------
# Epoch 37/1500
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.0172 ||Epoch_G_Loss:0.3052 ||Epoch_E_Loss:0.3077
# timer:  0.4238 sec.
# -------------
# Epoch 38/1500
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.0174 ||Epoch_G_Loss:0.3127 ||Epoch_E_Loss:0.2992
# timer:  0.4239 sec.
# -------------
# Epoch 39/1500
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.0161 ||Epoch_G_Loss:0.3188 ||Epoch_E_Loss:0.3147
# timer:  0.4219 sec.
# -------------
# Epoch 40/1500
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.0139 ||Epoch_G_Loss:0.3260 ||Epoch_E_Loss:0.3308
# timer:  0.4226 sec.
# -------------
# Epoch 41/1500
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.0151 ||Epoch_G_Loss:0.3271 ||Epoch_E_Loss:0.3166
# timer:  0.4246 sec.
# -------------
# Epoch 42/1500
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.0172 ||Epoch_G_Loss:0.3342 ||Epoch_E_Loss:0.2999
# timer:  0.4235 sec.
# -------------
# Epoch 43/1500
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.0158 ||Epoch_G_Loss:0.3399 ||Epoch_E_Loss:0.3137
# timer:  0.4257 sec.
# -------------
# Epoch 44/1500
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.0134 ||Epoch_G_Loss:0.3440 ||Epoch_E_Loss:0.3358
# timer:  0.4252 sec.
# -------------
# Epoch 45/1500
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.0114 ||Epoch_G_Loss:0.3539 ||Epoch_E_Loss:0.3566
# timer:  0.4236 sec.
# -------------
# Epoch 46/1500
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.0105 ||Epoch_G_Loss:0.3666 ||Epoch_E_Loss:0.3612
# timer:  0.4259 sec.
# -------------
# Epoch 47/1500
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.0098 ||Epoch_G_Loss:0.3699 ||Epoch_E_Loss:0.3669
# timer:  0.4241 sec.
# -------------
# Epoch 48/1500
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.0091 ||Epoch_G_Loss:0.3809 ||Epoch_E_Loss:0.3809
# timer:  0.4239 sec.
# -------------
# Epoch 49/1500
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.3851 ||Epoch_E_Loss:0.3944
# timer:  0.4257 sec.
# -------------
# Epoch 50/1500
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.0078 ||Epoch_G_Loss:0.3907 ||Epoch_E_Loss:0.4021
# timer:  0.4250 sec.
# -------------
# Epoch 51/1500
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.0075 ||Epoch_G_Loss:0.3924 ||Epoch_E_Loss:0.4051
# timer:  0.4256 sec.
# -------------
# Epoch 52/1500
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.0076 ||Epoch_G_Loss:0.3931 ||Epoch_E_Loss:0.4000
# timer:  0.4255 sec.
# -------------
# Epoch 53/1500
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.0082 ||Epoch_G_Loss:0.3937 ||Epoch_E_Loss:0.3910
# timer:  0.4262 sec.
# -------------
# Epoch 54/1500
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.0073 ||Epoch_G_Loss:0.3966 ||Epoch_E_Loss:0.4074
# timer:  0.4271 sec.
# -------------
# Epoch 55/1500
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.0064 ||Epoch_G_Loss:0.4047 ||Epoch_E_Loss:0.4267
# timer:  0.4266 sec.
# -------------
# Epoch 56/1500
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.0062 ||Epoch_G_Loss:0.4089 ||Epoch_E_Loss:0.4206
# timer:  0.4251 sec.
# -------------
# Epoch 57/1500
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.0070 ||Epoch_G_Loss:0.4088 ||Epoch_E_Loss:0.4098
# timer:  0.4265 sec.
# -------------
# Epoch 58/1500
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.0059 ||Epoch_G_Loss:0.4194 ||Epoch_E_Loss:0.4364
# timer:  0.4255 sec.
# -------------
# Epoch 59/1500
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.0057 ||Epoch_G_Loss:0.4174 ||Epoch_E_Loss:0.4386
# timer:  0.4265 sec.
# -------------
# Epoch 60/1500
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.4163 ||Epoch_E_Loss:0.4238
# timer:  0.4263 sec.
# -------------
# Epoch 61/1500
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.0072 ||Epoch_G_Loss:0.4159 ||Epoch_E_Loss:0.4129
# timer:  0.4249 sec.
# -------------
# Epoch 62/1500
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.0066 ||Epoch_G_Loss:0.4205 ||Epoch_E_Loss:0.4237
# timer:  0.4253 sec.
# -------------
# Epoch 63/1500
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.0066 ||Epoch_G_Loss:0.4239 ||Epoch_E_Loss:0.4241
# timer:  0.4251 sec.
# -------------
# Epoch 64/1500
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.0063 ||Epoch_G_Loss:0.4217 ||Epoch_E_Loss:0.4193
# timer:  0.4227 sec.
# -------------
# Epoch 65/1500
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.0060 ||Epoch_G_Loss:0.4269 ||Epoch_E_Loss:0.4274
# timer:  0.4260 sec.
# -------------
# Epoch 66/1500
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.0052 ||Epoch_G_Loss:0.4406 ||Epoch_E_Loss:0.4498
# timer:  0.4246 sec.
# -------------
# Epoch 67/1500
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.4422 ||Epoch_E_Loss:0.4540
# timer:  0.4251 sec.
# -------------
# Epoch 68/1500
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.0052 ||Epoch_G_Loss:0.4413 ||Epoch_E_Loss:0.4456
# timer:  0.4248 sec.
# -------------
# Epoch 69/1500
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.0055 ||Epoch_G_Loss:0.4389 ||Epoch_E_Loss:0.4416
# timer:  0.4241 sec.
# -------------
# Epoch 70/1500
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0053 ||Epoch_G_Loss:0.4504 ||Epoch_E_Loss:0.4470
# timer:  0.4259 sec.
# -------------
# Epoch 71/1500
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.0052 ||Epoch_G_Loss:0.4437 ||Epoch_E_Loss:0.4526
# timer:  0.4268 sec.
# -------------
# Epoch 72/1500
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0063 ||Epoch_G_Loss:0.4328 ||Epoch_E_Loss:0.4288
# timer:  0.4224 sec.
# -------------
# Epoch 73/1500
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0066 ||Epoch_G_Loss:0.4297 ||Epoch_E_Loss:0.4278
# timer:  0.4243 sec.
# -------------
# Epoch 74/1500
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.0064 ||Epoch_G_Loss:0.4317 ||Epoch_E_Loss:0.4294
# timer:  0.4246 sec.
# -------------
# Epoch 75/1500
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0064 ||Epoch_G_Loss:0.4359 ||Epoch_E_Loss:0.4260
# timer:  0.4234 sec.
# -------------
# Epoch 76/1500
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.0083 ||Epoch_G_Loss:0.4135 ||Epoch_E_Loss:0.4165
# timer:  0.4254 sec.
# -------------
# Epoch 77/1500
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0084 ||Epoch_G_Loss:0.4251 ||Epoch_E_Loss:0.4066
# timer:  0.4248 sec.
# -------------
# Epoch 78/1500
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0097 ||Epoch_G_Loss:0.3933 ||Epoch_E_Loss:0.3925
# timer:  0.4234 sec.
# -------------
# Epoch 79/1500
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0111 ||Epoch_G_Loss:0.4025 ||Epoch_E_Loss:0.3748
# timer:  0.4251 sec.
# -------------
# Epoch 80/1500
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0076 ||Epoch_G_Loss:0.4258 ||Epoch_E_Loss:0.4046
# timer:  0.4241 sec.
# -------------
# Epoch 81/1500
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0061 ||Epoch_G_Loss:0.4383 ||Epoch_E_Loss:0.4292
# timer:  0.4271 sec.
# -------------
# Epoch 82/1500
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0070 ||Epoch_G_Loss:0.4327 ||Epoch_E_Loss:0.4269
# timer:  0.4250 sec.
# -------------
# Epoch 83/1500
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.0088 ||Epoch_G_Loss:0.4192 ||Epoch_E_Loss:0.4139
# timer:  0.4222 sec.
# -------------
# Epoch 84/1500
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0191 ||Epoch_G_Loss:0.4008 ||Epoch_E_Loss:0.3760
# timer:  0.4245 sec.
# -------------
# Epoch 85/1500
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0164 ||Epoch_G_Loss:0.3818 ||Epoch_E_Loss:0.3734
# timer:  0.4257 sec.
# -------------
# Epoch 86/1500
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.0083 ||Epoch_G_Loss:0.4078 ||Epoch_E_Loss:0.4257
# timer:  0.4246 sec.
# -------------
# Epoch 87/1500
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0096 ||Epoch_G_Loss:0.4099 ||Epoch_E_Loss:0.4068
# timer:  0.4260 sec.
# -------------
# Epoch 88/1500
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.0127 ||Epoch_G_Loss:0.3724 ||Epoch_E_Loss:0.3926
# timer:  0.4250 sec.
# -------------
# Epoch 89/1500
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0171 ||Epoch_G_Loss:0.3673 ||Epoch_E_Loss:0.3732
# timer:  0.4260 sec.
# -------------
# Epoch 90/1500
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0183 ||Epoch_G_Loss:0.3842 ||Epoch_E_Loss:0.3668
# timer:  0.4250 sec.
# -------------
# Epoch 91/1500
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0112 ||Epoch_G_Loss:0.3972 ||Epoch_E_Loss:0.4082
# timer:  0.4240 sec.
# -------------
# Epoch 92/1500
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0157 ||Epoch_G_Loss:0.3444 ||Epoch_E_Loss:0.3965
# timer:  0.4246 sec.
# -------------
# Epoch 93/1500
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0428 ||Epoch_G_Loss:0.4179 ||Epoch_E_Loss:0.3926
# timer:  0.4253 sec.
# -------------
# Epoch 94/1500
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0174 ||Epoch_G_Loss:0.3783 ||Epoch_E_Loss:0.3753
# timer:  0.4249 sec.
# -------------
# Epoch 95/1500
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0170 ||Epoch_G_Loss:0.3705 ||Epoch_E_Loss:0.3749
# timer:  0.4249 sec.
# -------------
# Epoch 96/1500
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0217 ||Epoch_G_Loss:0.3199 ||Epoch_E_Loss:0.3826
# timer:  0.4249 sec.
# -------------
# Epoch 97/1500
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0279 ||Epoch_G_Loss:0.3460 ||Epoch_E_Loss:0.3609
# timer:  0.4260 sec.
# -------------
# Epoch 98/1500
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0294 ||Epoch_G_Loss:0.3047 ||Epoch_E_Loss:0.3395
# timer:  0.4254 sec.
# -------------
# Epoch 99/1500
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0320 ||Epoch_G_Loss:0.3398 ||Epoch_E_Loss:0.3132
# timer:  0.4236 sec.
# -------------
# Epoch 100/1500
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0225 ||Epoch_G_Loss:0.3644 ||Epoch_E_Loss:0.3796
# timer:  0.4256 sec.
# -------------
# Epoch 101/1500
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0236 ||Epoch_G_Loss:0.3424 ||Epoch_E_Loss:0.3569
# timer:  0.4247 sec.
# -------------
# Epoch 102/1500
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0228 ||Epoch_G_Loss:0.3273 ||Epoch_E_Loss:0.3581
# timer:  0.4239 sec.
# -------------
# Epoch 103/1500
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0287 ||Epoch_G_Loss:0.3356 ||Epoch_E_Loss:0.3319
# timer:  0.4257 sec.
# -------------
# Epoch 104/1500
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0316 ||Epoch_G_Loss:0.3012 ||Epoch_E_Loss:0.3524
# timer:  0.4260 sec.
# -------------
# Epoch 105/1500
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0324 ||Epoch_G_Loss:0.3296 ||Epoch_E_Loss:0.3509
# timer:  0.4250 sec.
# -------------
# Epoch 106/1500
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0278 ||Epoch_G_Loss:0.3205 ||Epoch_E_Loss:0.3572
# timer:  0.4251 sec.
# -------------
# Epoch 107/1500
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0518 ||Epoch_G_Loss:0.2679 ||Epoch_E_Loss:0.3360
# timer:  0.4244 sec.
# -------------
# Epoch 108/1500
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0761 ||Epoch_G_Loss:0.2868 ||Epoch_E_Loss:0.3107
# timer:  0.4261 sec.
# -------------
# Epoch 109/1500
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0386 ||Epoch_G_Loss:0.2954 ||Epoch_E_Loss:0.3184
# timer:  0.4248 sec.
# -------------
# Epoch 110/1500
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0704 ||Epoch_G_Loss:0.2145 ||Epoch_E_Loss:0.2775
# timer:  0.4251 sec.
# -------------
# Epoch 111/1500
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0568 ||Epoch_G_Loss:0.2765 ||Epoch_E_Loss:0.2859
# timer:  0.4256 sec.
# -------------
# Epoch 112/1500
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0668 ||Epoch_G_Loss:0.2653 ||Epoch_E_Loss:0.2826
# timer:  0.4241 sec.
# -------------
# Epoch 113/1500
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0745 ||Epoch_G_Loss:0.2346 ||Epoch_E_Loss:0.2730
# timer:  0.4256 sec.
# -------------
# Epoch 114/1500
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.1326 ||Epoch_G_Loss:0.1870 ||Epoch_E_Loss:0.2365
# timer:  0.4265 sec.
# -------------
# Epoch 115/1500
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0744 ||Epoch_G_Loss:0.2089 ||Epoch_E_Loss:0.2765
# timer:  0.4247 sec.
# -------------
# Epoch 116/1500
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0670 ||Epoch_G_Loss:0.2237 ||Epoch_E_Loss:0.2818
# timer:  0.4257 sec.
# -------------
# Epoch 117/1500
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0581 ||Epoch_G_Loss:0.2272 ||Epoch_E_Loss:0.2642
# timer:  0.4245 sec.
# -------------
# Epoch 118/1500
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0624 ||Epoch_G_Loss:0.2086 ||Epoch_E_Loss:0.2498
# timer:  0.4237 sec.
# -------------
# Epoch 119/1500
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0713 ||Epoch_G_Loss:0.2113 ||Epoch_E_Loss:0.2401
# timer:  0.4238 sec.
# -------------
# Epoch 120/1500
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0621 ||Epoch_G_Loss:0.2085 ||Epoch_E_Loss:0.2712
# timer:  0.4238 sec.
# -------------
# Epoch 121/1500
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0577 ||Epoch_G_Loss:0.2303 ||Epoch_E_Loss:0.2663
# timer:  0.4243 sec.
# -------------
# Epoch 122/1500
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0674 ||Epoch_G_Loss:0.2202 ||Epoch_E_Loss:0.2572
# timer:  0.4250 sec.
# -------------
# Epoch 123/1500
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0660 ||Epoch_G_Loss:0.2088 ||Epoch_E_Loss:0.2636
# timer:  0.4239 sec.
# -------------
# Epoch 124/1500
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0896 ||Epoch_G_Loss:0.1708 ||Epoch_E_Loss:0.2442
# timer:  0.4257 sec.
# -------------
# Epoch 125/1500
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0875 ||Epoch_G_Loss:0.1805 ||Epoch_E_Loss:0.2553
# timer:  0.4238 sec.
# -------------
# Epoch 126/1500
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0518 ||Epoch_G_Loss:0.2489 ||Epoch_E_Loss:0.2901
# timer:  0.4226 sec.
# -------------
# Epoch 127/1500
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0364 ||Epoch_G_Loss:0.2723 ||Epoch_E_Loss:0.3198
# timer:  0.4249 sec.
# -------------
# Epoch 128/1500
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0437 ||Epoch_G_Loss:0.2773 ||Epoch_E_Loss:0.2909
# timer:  0.4235 sec.
# -------------
# Epoch 129/1500
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0691 ||Epoch_G_Loss:0.2141 ||Epoch_E_Loss:0.2533
# timer:  0.4219 sec.
# -------------
# Epoch 130/1500
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.1287 ||Epoch_G_Loss:0.1487 ||Epoch_E_Loss:0.1854
# timer:  0.4246 sec.
# -------------
# Epoch 131/1500
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0904 ||Epoch_G_Loss:0.1750 ||Epoch_E_Loss:0.2264
# timer:  0.4223 sec.
# -------------
# Epoch 132/1500
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0507 ||Epoch_G_Loss:0.2278 ||Epoch_E_Loss:0.2666
# timer:  0.4232 sec.
# -------------
# Epoch 133/1500
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0471 ||Epoch_G_Loss:0.2293 ||Epoch_E_Loss:0.2683
# timer:  0.4228 sec.
# -------------
# Epoch 134/1500
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0610 ||Epoch_G_Loss:0.2232 ||Epoch_E_Loss:0.2413
# timer:  0.4206 sec.
# -------------
# Epoch 135/1500
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0687 ||Epoch_G_Loss:0.1785 ||Epoch_E_Loss:0.2413
# timer:  0.4236 sec.
# -------------
# Epoch 136/1500
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0740 ||Epoch_G_Loss:0.2012 ||Epoch_E_Loss:0.2238
# timer:  0.4232 sec.
# -------------
# Epoch 137/1500
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0619 ||Epoch_G_Loss:0.2000 ||Epoch_E_Loss:0.2329
# timer:  0.4212 sec.
# -------------
# Epoch 138/1500
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0618 ||Epoch_G_Loss:0.2043 ||Epoch_E_Loss:0.2445
# timer:  0.4233 sec.
# -------------
# Epoch 139/1500
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0619 ||Epoch_G_Loss:0.2259 ||Epoch_E_Loss:0.2292
# timer:  0.4213 sec.
# -------------
# Epoch 140/1500
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0650 ||Epoch_G_Loss:0.1871 ||Epoch_E_Loss:0.2414
# timer:  0.4247 sec.
# -------------
# Epoch 141/1500
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0679 ||Epoch_G_Loss:0.2274 ||Epoch_E_Loss:0.2269
# timer:  0.4230 sec.
# -------------
# Epoch 142/1500
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0593 ||Epoch_G_Loss:0.2196 ||Epoch_E_Loss:0.2447
# timer:  0.4216 sec.
# -------------
# Epoch 143/1500
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0666 ||Epoch_G_Loss:0.2029 ||Epoch_E_Loss:0.2221
# timer:  0.4252 sec.
# -------------
# Epoch 144/1500
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0923 ||Epoch_G_Loss:0.1671 ||Epoch_E_Loss:0.1927
# timer:  0.4228 sec.
# -------------
# Epoch 145/1500
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0944 ||Epoch_G_Loss:0.1762 ||Epoch_E_Loss:0.1960
# timer:  0.4210 sec.
# -------------
# Epoch 146/1500
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0656 ||Epoch_G_Loss:0.2154 ||Epoch_E_Loss:0.2361
# timer:  0.4246 sec.
# -------------
# Epoch 147/1500
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0508 ||Epoch_G_Loss:0.2288 ||Epoch_E_Loss:0.2525
# timer:  0.4243 sec.
# -------------
# Epoch 148/1500
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0508 ||Epoch_G_Loss:0.2279 ||Epoch_E_Loss:0.2514
# timer:  0.4213 sec.
# -------------
# Epoch 149/1500
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0635 ||Epoch_G_Loss:0.1853 ||Epoch_E_Loss:0.2181
# timer:  0.4251 sec.
# -------------
# Epoch 150/1500
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0699 ||Epoch_G_Loss:0.1715 ||Epoch_E_Loss:0.2197
# timer:  0.4233 sec.
# -------------
# Epoch 151/1500
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0698 ||Epoch_G_Loss:0.2010 ||Epoch_E_Loss:0.2219
# timer:  0.4254 sec.
# -------------
# Epoch 152/1500
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0550 ||Epoch_G_Loss:0.2271 ||Epoch_E_Loss:0.2465
# timer:  0.4243 sec.
# -------------
# Epoch 153/1500
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0600 ||Epoch_G_Loss:0.2155 ||Epoch_E_Loss:0.2347
# timer:  0.4230 sec.
# -------------
# Epoch 154/1500
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0885 ||Epoch_G_Loss:0.1568 ||Epoch_E_Loss:0.2258
# timer:  0.4235 sec.
# -------------
# Epoch 155/1500
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0943 ||Epoch_G_Loss:0.1548 ||Epoch_E_Loss:0.1976
# timer:  0.4232 sec.
# -------------
# Epoch 156/1500
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0857 ||Epoch_G_Loss:0.1907 ||Epoch_E_Loss:0.2103
# timer:  0.4222 sec.
# -------------
# Epoch 157/1500
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0663 ||Epoch_G_Loss:0.2294 ||Epoch_E_Loss:0.2274
# timer:  0.4226 sec.
# -------------
# Epoch 158/1500
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0622 ||Epoch_G_Loss:0.2400 ||Epoch_E_Loss:0.2250
# timer:  0.4212 sec.
# -------------
# Epoch 159/1500
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0706 ||Epoch_G_Loss:0.1987 ||Epoch_E_Loss:0.2192
# timer:  0.4235 sec.
# -------------
# Epoch 160/1500
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0857 ||Epoch_G_Loss:0.2006 ||Epoch_E_Loss:0.1894
# timer:  0.4257 sec.
# -------------
# Epoch 161/1500
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0884 ||Epoch_G_Loss:0.1845 ||Epoch_E_Loss:0.2204
# timer:  0.4196 sec.
# -------------
# Epoch 162/1500
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0925 ||Epoch_G_Loss:0.1995 ||Epoch_E_Loss:0.2033
# timer:  0.4233 sec.
# -------------
# Epoch 163/1500
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.1540 ||Epoch_E_Loss:0.2073
# timer:  0.4214 sec.
# -------------
# Epoch 164/1500
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.1295 ||Epoch_G_Loss:0.1502 ||Epoch_E_Loss:0.1731
# timer:  0.4208 sec.
# -------------
# Epoch 165/1500
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.1292 ||Epoch_G_Loss:0.1360 ||Epoch_E_Loss:0.1765
# timer:  0.4231 sec.
# -------------
# Epoch 166/1500
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0925 ||Epoch_G_Loss:0.1819 ||Epoch_E_Loss:0.2084
# timer:  0.4183 sec.
# -------------
# Epoch 167/1500
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0640 ||Epoch_G_Loss:0.2120 ||Epoch_E_Loss:0.2383
# timer:  0.4225 sec.
# -------------
# Epoch 168/1500
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0657 ||Epoch_G_Loss:0.2177 ||Epoch_E_Loss:0.2402
# timer:  0.4237 sec.
# -------------
# Epoch 169/1500
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0830 ||Epoch_G_Loss:0.1901 ||Epoch_E_Loss:0.2051
# timer:  0.4187 sec.
# -------------
# Epoch 170/1500
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.1116 ||Epoch_G_Loss:0.1713 ||Epoch_E_Loss:0.1978
# timer:  0.4247 sec.
# -------------
# Epoch 171/1500
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.1187 ||Epoch_G_Loss:0.1659 ||Epoch_E_Loss:0.1798
# timer:  0.4246 sec.
# -------------
# Epoch 172/1500
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.1338 ||Epoch_G_Loss:0.1387 ||Epoch_E_Loss:0.1735
# timer:  0.4213 sec.
# -------------
# Epoch 173/1500
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.1217 ||Epoch_G_Loss:0.1555 ||Epoch_E_Loss:0.1770
# timer:  0.4231 sec.
# -------------
# Epoch 174/1500
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.1156 ||Epoch_G_Loss:0.1540 ||Epoch_E_Loss:0.1770
# timer:  0.4201 sec.
# -------------
# Epoch 175/1500
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.1115 ||Epoch_G_Loss:0.1458 ||Epoch_E_Loss:0.1734
# timer:  0.4223 sec.
# -------------
# Epoch 176/1500
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.1168 ||Epoch_G_Loss:0.1363 ||Epoch_E_Loss:0.1644
# timer:  0.4223 sec.
# -------------
# Epoch 177/1500
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.1039 ||Epoch_G_Loss:0.1526 ||Epoch_E_Loss:0.1722
# timer:  0.4189 sec.
# -------------
# Epoch 178/1500
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0988 ||Epoch_G_Loss:0.1779 ||Epoch_E_Loss:0.1704
# timer:  0.4248 sec.
# -------------
# Epoch 179/1500
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1790 ||Epoch_E_Loss:0.1784
# timer:  0.4241 sec.
# -------------
# Epoch 180/1500
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0903 ||Epoch_G_Loss:0.1778 ||Epoch_E_Loss:0.1725
# timer:  0.4217 sec.
# -------------
# Epoch 181/1500
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0959 ||Epoch_G_Loss:0.1756 ||Epoch_E_Loss:0.1753
# timer:  0.4233 sec.
# -------------
# Epoch 182/1500
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0884 ||Epoch_G_Loss:0.1563 ||Epoch_E_Loss:0.1822
# timer:  0.4221 sec.
# -------------
# Epoch 183/1500
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0841 ||Epoch_G_Loss:0.1713 ||Epoch_E_Loss:0.1892
# timer:  0.4220 sec.
# -------------
# Epoch 184/1500
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0677 ||Epoch_G_Loss:0.2057 ||Epoch_E_Loss:0.2026
# timer:  0.4204 sec.
# -------------
# Epoch 185/1500
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0653 ||Epoch_G_Loss:0.2132 ||Epoch_E_Loss:0.2145
# timer:  0.4238 sec.
# -------------
# Epoch 186/1500
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0681 ||Epoch_G_Loss:0.2036 ||Epoch_E_Loss:0.2103
# timer:  0.4277 sec.
# -------------
# Epoch 187/1500
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0762 ||Epoch_G_Loss:0.1715 ||Epoch_E_Loss:0.2026
# timer:  0.4312 sec.
# -------------
# Epoch 188/1500
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0945 ||Epoch_G_Loss:0.1722 ||Epoch_E_Loss:0.1752
# timer:  0.4306 sec.
# -------------
# Epoch 189/1500
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0913 ||Epoch_G_Loss:0.1613 ||Epoch_E_Loss:0.1817
# timer:  0.4316 sec.
# -------------
# Epoch 190/1500
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0882 ||Epoch_G_Loss:0.1723 ||Epoch_E_Loss:0.1961
# timer:  0.4301 sec.
# -------------
# Epoch 191/1500
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0809 ||Epoch_G_Loss:0.1827 ||Epoch_E_Loss:0.1976
# timer:  0.4311 sec.
# -------------
# Epoch 192/1500
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0785 ||Epoch_G_Loss:0.1661 ||Epoch_E_Loss:0.2009
# timer:  0.4306 sec.
# -------------
# Epoch 193/1500
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0865 ||Epoch_G_Loss:0.1758 ||Epoch_E_Loss:0.1856
# timer:  0.4275 sec.
# -------------
# Epoch 194/1500
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0968 ||Epoch_G_Loss:0.1709 ||Epoch_E_Loss:0.1753
# timer:  0.4275 sec.
# -------------
# Epoch 195/1500
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.1059 ||Epoch_G_Loss:0.1581 ||Epoch_E_Loss:0.1684
# timer:  0.4273 sec.
# -------------
# Epoch 196/1500
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.1164 ||Epoch_G_Loss:0.1516 ||Epoch_E_Loss:0.1522
# timer:  0.4271 sec.
# -------------
# Epoch 197/1500
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.1210 ||Epoch_G_Loss:0.1352 ||Epoch_E_Loss:0.1578
# timer:  0.4282 sec.
# -------------
# Epoch 198/1500
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.1283 ||Epoch_G_Loss:0.1533 ||Epoch_E_Loss:0.1512
# timer:  0.4263 sec.
# -------------
# Epoch 199/1500
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.1150 ||Epoch_G_Loss:0.1534 ||Epoch_E_Loss:0.1674
# timer:  0.4248 sec.
# -------------
# Epoch 200/1500
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.1032 ||Epoch_G_Loss:0.1505 ||Epoch_E_Loss:0.1831
# timer:  0.4268 sec.
# -------------
# Epoch 201/1500
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.0994 ||Epoch_G_Loss:0.1569 ||Epoch_E_Loss:0.1810
# timer:  0.4244 sec.
# -------------
# Epoch 202/1500
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.0911 ||Epoch_G_Loss:0.1673 ||Epoch_E_Loss:0.1922
# timer:  0.4263 sec.
# -------------
# Epoch 203/1500
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.0946 ||Epoch_G_Loss:0.1785 ||Epoch_E_Loss:0.1888
# timer:  0.4249 sec.
# -------------
# Epoch 204/1500
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.0805 ||Epoch_G_Loss:0.1863 ||Epoch_E_Loss:0.1936
# timer:  0.4215 sec.
# -------------
# Epoch 205/1500
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.0954 ||Epoch_G_Loss:0.1560 ||Epoch_E_Loss:0.1855
# timer:  0.4255 sec.
# -------------
# Epoch 206/1500
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.1073 ||Epoch_G_Loss:0.1463 ||Epoch_E_Loss:0.1660
# timer:  0.4240 sec.
# -------------
# Epoch 207/1500
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.1215 ||Epoch_G_Loss:0.1488 ||Epoch_E_Loss:0.1524
# timer:  0.4238 sec.
# -------------
# Epoch 208/1500
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.1210 ||Epoch_G_Loss:0.1447 ||Epoch_E_Loss:0.1496
# timer:  0.4258 sec.
# -------------
# Epoch 209/1500
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.0934 ||Epoch_G_Loss:0.1430 ||Epoch_E_Loss:0.1758
# timer:  0.4234 sec.
# -------------
# Epoch 210/1500
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.0915 ||Epoch_G_Loss:0.1484 ||Epoch_E_Loss:0.1760
# timer:  0.4220 sec.
# -------------
# Epoch 211/1500
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.0888 ||Epoch_G_Loss:0.1500 ||Epoch_E_Loss:0.1773
# timer:  0.4238 sec.
# -------------
# Epoch 212/1500
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.0913 ||Epoch_G_Loss:0.1522 ||Epoch_E_Loss:0.1756
# timer:  0.4208 sec.
# -------------
# Epoch 213/1500
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.0978 ||Epoch_G_Loss:0.1590 ||Epoch_E_Loss:0.1625
# timer:  0.4223 sec.
# -------------
# Epoch 214/1500
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.1518 ||Epoch_E_Loss:0.1452
# timer:  0.4247 sec.
# -------------
# Epoch 215/1500
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.1344 ||Epoch_G_Loss:0.1267 ||Epoch_E_Loss:0.1488
# timer:  0.4224 sec.
# -------------
# Epoch 216/1500
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.1341 ||Epoch_G_Loss:0.1245 ||Epoch_E_Loss:0.1305
# timer:  0.4251 sec.
# -------------
# Epoch 217/1500
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.1297 ||Epoch_G_Loss:0.1278 ||Epoch_E_Loss:0.1321
# timer:  0.4218 sec.
# -------------
# Epoch 218/1500
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.1213 ||Epoch_G_Loss:0.1380 ||Epoch_E_Loss:0.1341
# timer:  0.4207 sec.
# -------------
# Epoch 219/1500
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.1129 ||Epoch_G_Loss:0.1416 ||Epoch_E_Loss:0.1443
# timer:  0.4241 sec.
# -------------
# Epoch 220/1500
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.1052 ||Epoch_G_Loss:0.1404 ||Epoch_E_Loss:0.1512
# timer:  0.4222 sec.
# -------------
# Epoch 221/1500
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.1106 ||Epoch_G_Loss:0.1724 ||Epoch_E_Loss:0.1350
# timer:  0.4272 sec.
# -------------
# Epoch 222/1500
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.1028 ||Epoch_G_Loss:0.1524 ||Epoch_E_Loss:0.1653
# timer:  0.4274 sec.
# -------------
# Epoch 223/1500
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.1047 ||Epoch_G_Loss:0.1602 ||Epoch_E_Loss:0.1528
# timer:  0.4249 sec.
# -------------
# Epoch 224/1500
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.1005 ||Epoch_G_Loss:0.1487 ||Epoch_E_Loss:0.1530
# timer:  0.4265 sec.
# -------------
# Epoch 225/1500
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.1084 ||Epoch_G_Loss:0.1387 ||Epoch_E_Loss:0.1529
# timer:  0.4266 sec.
# -------------
# Epoch 226/1500
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.1170 ||Epoch_G_Loss:0.1356 ||Epoch_E_Loss:0.1424
# timer:  0.4254 sec.
# -------------
# Epoch 227/1500
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.1243 ||Epoch_G_Loss:0.1356 ||Epoch_E_Loss:0.1418
# timer:  0.4265 sec.
# -------------
# Epoch 228/1500
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.1350 ||Epoch_G_Loss:0.1225 ||Epoch_E_Loss:0.1341
# timer:  0.4258 sec.
# -------------
# Epoch 229/1500
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.1327 ||Epoch_G_Loss:0.1173 ||Epoch_E_Loss:0.1315
# timer:  0.4260 sec.
# -------------
# Epoch 230/1500
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.1356 ||Epoch_G_Loss:0.1319 ||Epoch_E_Loss:0.1306
# timer:  0.4257 sec.
# -------------
# Epoch 231/1500
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.1276 ||Epoch_G_Loss:0.1180 ||Epoch_E_Loss:0.1300
# timer:  0.4277 sec.
# -------------
# Epoch 232/1500
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.1248 ||Epoch_G_Loss:0.1192 ||Epoch_E_Loss:0.1348
# timer:  0.4289 sec.
# -------------
# Epoch 233/1500
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.1205 ||Epoch_G_Loss:0.1125 ||Epoch_E_Loss:0.1356
# timer:  0.4284 sec.
# -------------
# Epoch 234/1500
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.1223 ||Epoch_G_Loss:0.1304 ||Epoch_E_Loss:0.1316
# timer:  0.4274 sec.
# -------------
# Epoch 235/1500
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.1235 ||Epoch_G_Loss:0.1448 ||Epoch_E_Loss:0.1275
# timer:  0.4299 sec.
# -------------
# Epoch 236/1500
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.1390 ||Epoch_G_Loss:0.1178 ||Epoch_E_Loss:0.1282
# timer:  0.4279 sec.
# -------------
# Epoch 237/1500
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.1323 ||Epoch_G_Loss:0.1097 ||Epoch_E_Loss:0.1248
# timer:  0.4273 sec.
# -------------
# Epoch 238/1500
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.1386 ||Epoch_G_Loss:0.1181 ||Epoch_E_Loss:0.1237
# timer:  0.4247 sec.
# -------------
# Epoch 239/1500
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.1373 ||Epoch_G_Loss:0.1262 ||Epoch_E_Loss:0.1224
# timer:  0.4250 sec.
# -------------
# Epoch 240/1500
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.1374 ||Epoch_G_Loss:0.1133 ||Epoch_E_Loss:0.1242
# timer:  0.4260 sec.
# -------------
# Epoch 241/1500
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.1437 ||Epoch_G_Loss:0.1209 ||Epoch_E_Loss:0.1163
# timer:  0.4236 sec.
# -------------
# Epoch 242/1500
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.1424 ||Epoch_G_Loss:0.1176 ||Epoch_E_Loss:0.1175
# timer:  0.4255 sec.
# -------------
# Epoch 243/1500
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.1349 ||Epoch_G_Loss:0.1145 ||Epoch_E_Loss:0.1233
# timer:  0.4263 sec.
# -------------
# Epoch 244/1500
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.1502 ||Epoch_G_Loss:0.1104 ||Epoch_E_Loss:0.1080
# timer:  0.4243 sec.
# -------------
# Epoch 245/1500
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.1316 ||Epoch_G_Loss:0.1118 ||Epoch_E_Loss:0.1243
# timer:  0.4254 sec.
# -------------
# Epoch 246/1500
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.1302 ||Epoch_G_Loss:0.1228 ||Epoch_E_Loss:0.1219
# timer:  0.4257 sec.
# -------------
# Epoch 247/1500
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.1255 ||Epoch_G_Loss:0.1285 ||Epoch_E_Loss:0.1249
# timer:  0.4237 sec.
# -------------
# Epoch 248/1500
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.1253 ||Epoch_G_Loss:0.1204 ||Epoch_E_Loss:0.1244
# timer:  0.4260 sec.
# -------------
# Epoch 249/1500
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.1269 ||Epoch_G_Loss:0.1335 ||Epoch_E_Loss:0.1262
# timer:  0.4268 sec.
# -------------
# Epoch 250/1500
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.1217 ||Epoch_G_Loss:0.1264 ||Epoch_E_Loss:0.1305
# timer:  0.4279 sec.
# -------------
# Epoch 251/1500
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.1260 ||Epoch_G_Loss:0.1262 ||Epoch_E_Loss:0.1235
# timer:  0.4291 sec.
# -------------
# Epoch 252/1500
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.1152 ||Epoch_G_Loss:0.1336 ||Epoch_E_Loss:0.1312
# timer:  0.4268 sec.
# -------------
# Epoch 253/1500
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.1244 ||Epoch_G_Loss:0.1267 ||Epoch_E_Loss:0.1239
# timer:  0.4249 sec.
# -------------
# Epoch 254/1500
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.1240 ||Epoch_G_Loss:0.1433 ||Epoch_E_Loss:0.1247
# timer:  0.4258 sec.
# -------------
# Epoch 255/1500
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.1199 ||Epoch_E_Loss:0.1345
# timer:  0.4233 sec.
# -------------
# Epoch 256/1500
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.1218 ||Epoch_G_Loss:0.1298 ||Epoch_E_Loss:0.1260
# timer:  0.4255 sec.
# -------------
# Epoch 257/1500
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.1156 ||Epoch_G_Loss:0.1364 ||Epoch_E_Loss:0.1283
# timer:  0.4254 sec.
# -------------
# Epoch 258/1500
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.1198 ||Epoch_G_Loss:0.1313 ||Epoch_E_Loss:0.1298
# timer:  0.4240 sec.
# -------------
# Epoch 259/1500
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.1197 ||Epoch_G_Loss:0.1336 ||Epoch_E_Loss:0.1257
# timer:  0.4263 sec.
# -------------
# Epoch 260/1500
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.1217 ||Epoch_G_Loss:0.1365 ||Epoch_E_Loss:0.1300
# timer:  0.4323 sec.
# -------------
# Epoch 261/1500
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.1154 ||Epoch_G_Loss:0.1288 ||Epoch_E_Loss:0.1294
# timer:  0.4290 sec.
# -------------
# Epoch 262/1500
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.1249 ||Epoch_G_Loss:0.1282 ||Epoch_E_Loss:0.1230
# timer:  0.4319 sec.
# -------------
# Epoch 263/1500
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.1316 ||Epoch_G_Loss:0.1242 ||Epoch_E_Loss:0.1169
# timer:  0.4314 sec.
# -------------
# Epoch 264/1500
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.1313 ||Epoch_G_Loss:0.1299 ||Epoch_E_Loss:0.1233
# timer:  0.4316 sec.
# -------------
# Epoch 265/1500
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.1282 ||Epoch_G_Loss:0.1417 ||Epoch_E_Loss:0.1198
# timer:  0.4311 sec.
# -------------
# Epoch 266/1500
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.1291 ||Epoch_G_Loss:0.1309 ||Epoch_E_Loss:0.1211
# timer:  0.4297 sec.
# -------------
# Epoch 267/1500
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.1282 ||Epoch_G_Loss:0.1258 ||Epoch_E_Loss:0.1233
# timer:  0.4315 sec.
# -------------
# Epoch 268/1500
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.1328 ||Epoch_G_Loss:0.1246 ||Epoch_E_Loss:0.1200
# timer:  0.4303 sec.
# -------------
# Epoch 269/1500
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.1229 ||Epoch_G_Loss:0.1187 ||Epoch_E_Loss:0.1274
# timer:  0.4288 sec.
# -------------
# Epoch 270/1500
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.1268 ||Epoch_G_Loss:0.1207 ||Epoch_E_Loss:0.1259
# timer:  0.4303 sec.
# -------------
# Epoch 271/1500
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.1211 ||Epoch_G_Loss:0.1218 ||Epoch_E_Loss:0.1275
# timer:  0.4288 sec.
# -------------
# Epoch 272/1500
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.1111 ||Epoch_G_Loss:0.1367 ||Epoch_E_Loss:0.1379
# timer:  0.4307 sec.
# -------------
# Epoch 273/1500
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.1073 ||Epoch_G_Loss:0.1510 ||Epoch_E_Loss:0.1413
# timer:  0.4314 sec.
# -------------
# Epoch 274/1500
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.1038 ||Epoch_G_Loss:0.1558 ||Epoch_E_Loss:0.1435
# timer:  0.4296 sec.
# -------------
# Epoch 275/1500
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.0993 ||Epoch_G_Loss:0.1366 ||Epoch_E_Loss:0.1517
# timer:  0.4308 sec.
# -------------
# Epoch 276/1500
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.1091 ||Epoch_G_Loss:0.1520 ||Epoch_E_Loss:0.1427
# timer:  0.4308 sec.
# -------------
# Epoch 277/1500
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.1163 ||Epoch_G_Loss:0.1423 ||Epoch_E_Loss:0.1360
# timer:  0.4304 sec.
# -------------
# Epoch 278/1500
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.1336 ||Epoch_G_Loss:0.1240 ||Epoch_E_Loss:0.1264
# timer:  0.4321 sec.
# -------------
# Epoch 279/1500
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.1319 ||Epoch_G_Loss:0.1144 ||Epoch_E_Loss:0.1280
# timer:  0.4306 sec.
# -------------
# Epoch 280/1500
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.1350 ||Epoch_G_Loss:0.1250 ||Epoch_E_Loss:0.1246
# timer:  0.4305 sec.
# -------------
# Epoch 281/1500
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.1354 ||Epoch_G_Loss:0.1266 ||Epoch_E_Loss:0.1287
# timer:  0.4295 sec.
# -------------
# Epoch 282/1500
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.1262 ||Epoch_G_Loss:0.1236 ||Epoch_E_Loss:0.1255
# timer:  0.4292 sec.
# -------------
# Epoch 283/1500
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.1136 ||Epoch_G_Loss:0.1407 ||Epoch_E_Loss:0.1363
# timer:  0.4321 sec.
# -------------
# Epoch 284/1500
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.1126 ||Epoch_G_Loss:0.1445 ||Epoch_E_Loss:0.1367
# timer:  0.4310 sec.
# -------------
# Epoch 285/1500
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.1052 ||Epoch_G_Loss:0.1487 ||Epoch_E_Loss:0.1427
# timer:  0.4317 sec.
# -------------
# Epoch 286/1500
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.1023 ||Epoch_G_Loss:0.1472 ||Epoch_E_Loss:0.1459
# timer:  0.4303 sec.
# -------------
# Epoch 287/1500
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.1018 ||Epoch_G_Loss:0.1591 ||Epoch_E_Loss:0.1413
# timer:  0.4291 sec.
# -------------
# Epoch 288/1500
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.1142 ||Epoch_G_Loss:0.1532 ||Epoch_E_Loss:0.1379
# timer:  0.4298 sec.
# -------------
# Epoch 289/1500
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.1259 ||Epoch_G_Loss:0.1368 ||Epoch_E_Loss:0.1262
# timer:  0.4305 sec.
# -------------
# Epoch 290/1500
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.1351 ||Epoch_G_Loss:0.1240 ||Epoch_E_Loss:0.1219
# timer:  0.4299 sec.
# -------------
# Epoch 291/1500
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.1626 ||Epoch_G_Loss:0.1159 ||Epoch_E_Loss:0.1009
# timer:  0.4316 sec.
# -------------
# Epoch 292/1500
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.1685 ||Epoch_G_Loss:0.1141 ||Epoch_E_Loss:0.1030
# timer:  0.4310 sec.
# -------------
# Epoch 293/1500
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.1598 ||Epoch_G_Loss:0.1124 ||Epoch_E_Loss:0.1021
# timer:  0.4293 sec.
# -------------
# Epoch 294/1500
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.1485 ||Epoch_G_Loss:0.1166 ||Epoch_E_Loss:0.1086
# timer:  0.4321 sec.
# -------------
# Epoch 295/1500
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.1359 ||Epoch_G_Loss:0.1299 ||Epoch_E_Loss:0.1178
# timer:  0.4300 sec.
# -------------
# Epoch 296/1500
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.1167 ||Epoch_G_Loss:0.1307 ||Epoch_E_Loss:0.1305
# timer:  0.4319 sec.
# -------------
# Epoch 297/1500
# -------------
# （train）
# -------------
# ...
# timer:  0.4306 sec.
# -------------
# Epoch 1403/1500
# -------------
# （train）
# -------------
# epoch 1403 || Epoch_D_Loss:0.1064 ||Epoch_G_Loss:0.1578 ||Epoch_E_Loss:0.1378
# timer:  0.4310 sec.
# -------------
# Epoch 1404/1500
# -------------
# （train）
# -------------
# epoch 1404 || Epoch_D_Loss:0.0924 ||Epoch_G_Loss:0.1319 ||Epoch_E_Loss:0.1598
# timer:  0.4298 sec.
# -------------
# Epoch 1405/1500
# -------------
# （train）
# -------------
# epoch 1405 || Epoch_D_Loss:0.0988 ||Epoch_G_Loss:0.1659 ||Epoch_E_Loss:0.1509
# timer:  0.4303 sec.
# -------------
# Epoch 1406/1500
# -------------
# （train）
# -------------
# epoch 1406 || Epoch_D_Loss:0.0892 ||Epoch_G_Loss:0.1439 ||Epoch_E_Loss:0.1669
# timer:  0.4287 sec.
# -------------
# Epoch 1407/1500
# -------------
# （train）
# -------------
# epoch 1407 || Epoch_D_Loss:0.1026 ||Epoch_G_Loss:0.1553 ||Epoch_E_Loss:0.1485
# timer:  0.4310 sec.
# -------------
# Epoch 1408/1500
# -------------
# （train）
# -------------
# epoch 1408 || Epoch_D_Loss:0.0919 ||Epoch_G_Loss:0.1426 ||Epoch_E_Loss:0.1597
# timer:  0.4299 sec.
# -------------
# Epoch 1409/1500
# -------------
# （train）
# -------------
# epoch 1409 || Epoch_D_Loss:0.0980 ||Epoch_G_Loss:0.1447 ||Epoch_E_Loss:0.1570
# timer:  0.4306 sec.
# -------------
# Epoch 1410/1500
# -------------
# （train）
# -------------
# epoch 1410 || Epoch_D_Loss:0.1048 ||Epoch_G_Loss:0.1407 ||Epoch_E_Loss:0.1566
# timer:  0.4293 sec.
# -------------
# Epoch 1411/1500
# -------------
# （train）
# -------------
# epoch 1411 || Epoch_D_Loss:0.1147 ||Epoch_G_Loss:0.1146 ||Epoch_E_Loss:0.1458
# timer:  0.4284 sec.
# -------------
# Epoch 1412/1500
# -------------
# （train）
# -------------
# epoch 1412 || Epoch_D_Loss:0.1219 ||Epoch_G_Loss:0.1269 ||Epoch_E_Loss:0.1338
# timer:  0.4302 sec.
# -------------
# Epoch 1413/1500
# -------------
# （train）
# -------------
# epoch 1413 || Epoch_D_Loss:0.1053 ||Epoch_G_Loss:0.1424 ||Epoch_E_Loss:0.1572
# timer:  0.4284 sec.
# -------------
# Epoch 1414/1500
# -------------
# （train）
# -------------
# epoch 1414 || Epoch_D_Loss:0.0943 ||Epoch_G_Loss:0.1328 ||Epoch_E_Loss:0.1608
# timer:  0.4293 sec.
# -------------
# Epoch 1415/1500
# -------------
# （train）
# -------------
# epoch 1415 || Epoch_D_Loss:0.1224 ||Epoch_G_Loss:0.1417 ||Epoch_E_Loss:0.1429
# timer:  0.4303 sec.
# -------------
# Epoch 1416/1500
# -------------
# （train）
# -------------
# epoch 1416 || Epoch_D_Loss:0.1121 ||Epoch_G_Loss:0.1222 ||Epoch_E_Loss:0.1495
# timer:  0.4299 sec.
# -------------
# Epoch 1417/1500
# -------------
# （train）
# -------------
# epoch 1417 || Epoch_D_Loss:0.1087 ||Epoch_G_Loss:0.1359 ||Epoch_E_Loss:0.1534
# timer:  0.4305 sec.
# -------------
# Epoch 1418/1500
# -------------
# （train）
# -------------
# epoch 1418 || Epoch_D_Loss:0.0923 ||Epoch_G_Loss:0.1493 ||Epoch_E_Loss:0.1559
# timer:  0.4305 sec.
# -------------
# Epoch 1419/1500
# -------------
# （train）
# -------------
# epoch 1419 || Epoch_D_Loss:0.0886 ||Epoch_G_Loss:0.1573 ||Epoch_E_Loss:0.1553
# timer:  0.4290 sec.
# -------------
# Epoch 1420/1500
# -------------
# （train）
# -------------
# epoch 1420 || Epoch_D_Loss:0.0956 ||Epoch_G_Loss:0.1369 ||Epoch_E_Loss:0.1670
# timer:  0.4306 sec.
# -------------
# Epoch 1421/1500
# -------------
# （train）
# -------------
# epoch 1421 || Epoch_D_Loss:0.0943 ||Epoch_G_Loss:0.1680 ||Epoch_E_Loss:0.1471
# timer:  0.4306 sec.
# -------------
# Epoch 1422/1500
# -------------
# （train）
# -------------
# epoch 1422 || Epoch_D_Loss:0.0978 ||Epoch_G_Loss:0.1442 ||Epoch_E_Loss:0.1557
# timer:  0.4303 sec.
# -------------
# Epoch 1423/1500
# -------------
# （train）
# -------------
# epoch 1423 || Epoch_D_Loss:0.0968 ||Epoch_G_Loss:0.1424 ||Epoch_E_Loss:0.1475
# timer:  0.4300 sec.
# -------------
# Epoch 1424/1500
# -------------
# （train）
# -------------
# epoch 1424 || Epoch_D_Loss:0.0922 ||Epoch_G_Loss:0.1453 ||Epoch_E_Loss:0.1611
# timer:  0.4296 sec.
# -------------
# Epoch 1425/1500
# -------------
# （train）
# -------------
# epoch 1425 || Epoch_D_Loss:0.0875 ||Epoch_G_Loss:0.1486 ||Epoch_E_Loss:0.1587
# timer:  0.4308 sec.
# -------------
# Epoch 1426/1500
# -------------
# （train）
# -------------
# epoch 1426 || Epoch_D_Loss:0.0871 ||Epoch_G_Loss:0.1656 ||Epoch_E_Loss:0.1528
# timer:  0.4289 sec.
# -------------
# Epoch 1427/1500
# -------------
# （train）
# -------------
# epoch 1427 || Epoch_D_Loss:0.0899 ||Epoch_G_Loss:0.1493 ||Epoch_E_Loss:0.1629
# timer:  0.4296 sec.
# -------------
# Epoch 1428/1500
# -------------
# （train）
# -------------
# epoch 1428 || Epoch_D_Loss:0.0948 ||Epoch_G_Loss:0.1585 ||Epoch_E_Loss:0.1557
# timer:  0.4306 sec.
# -------------
# Epoch 1429/1500
# -------------
# （train）
# -------------
# epoch 1429 || Epoch_D_Loss:0.0917 ||Epoch_G_Loss:0.1426 ||Epoch_E_Loss:0.1531
# timer:  0.4301 sec.
# -------------
# Epoch 1430/1500
# -------------
# （train）
# -------------
# epoch 1430 || Epoch_D_Loss:0.1032 ||Epoch_G_Loss:0.1499 ||Epoch_E_Loss:0.1421
# timer:  0.4297 sec.
# -------------
# Epoch 1431/1500
# -------------
# （train）
# -------------
# epoch 1431 || Epoch_D_Loss:0.0939 ||Epoch_G_Loss:0.1442 ||Epoch_E_Loss:0.1666
# timer:  0.4298 sec.
# -------------
# Epoch 1432/1500
# -------------
# （train）
# -------------
# epoch 1432 || Epoch_D_Loss:0.0993 ||Epoch_G_Loss:0.1450 ||Epoch_E_Loss:0.1524
# timer:  0.4268 sec.
# -------------
# Epoch 1433/1500
# -------------
# （train）
# -------------
# epoch 1433 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.1445 ||Epoch_E_Loss:0.1518
# timer:  0.4304 sec.
# -------------
# Epoch 1434/1500
# -------------
# （train）
# -------------
# epoch 1434 || Epoch_D_Loss:0.0886 ||Epoch_G_Loss:0.1488 ||Epoch_E_Loss:0.1687
# timer:  0.4291 sec.
# -------------
# Epoch 1435/1500
# -------------
# （train）
# -------------
# epoch 1435 || Epoch_D_Loss:0.0850 ||Epoch_G_Loss:0.1679 ||Epoch_E_Loss:0.1649
# timer:  0.4285 sec.
# -------------
# Epoch 1436/1500
# -------------
# （train）
# -------------
# epoch 1436 || Epoch_D_Loss:0.0808 ||Epoch_G_Loss:0.1599 ||Epoch_E_Loss:0.1652
# timer:  0.4302 sec.
# -------------
# Epoch 1437/1500
# -------------
# （train）
# -------------
# epoch 1437 || Epoch_D_Loss:0.0861 ||Epoch_G_Loss:0.1556 ||Epoch_E_Loss:0.1597
# timer:  0.4293 sec.
# -------------
# Epoch 1438/1500
# -------------
# （train）
# -------------
# epoch 1438 || Epoch_D_Loss:0.0971 ||Epoch_G_Loss:0.1364 ||Epoch_E_Loss:0.1506
# timer:  0.4302 sec.
# -------------
# Epoch 1439/1500
# -------------
# （train）
# -------------
# epoch 1439 || Epoch_D_Loss:0.1155 ||Epoch_G_Loss:0.1505 ||Epoch_E_Loss:0.1277
# timer:  0.4307 sec.
# -------------
# Epoch 1440/1500
# -------------
# （train）
# -------------
# epoch 1440 || Epoch_D_Loss:0.1063 ||Epoch_G_Loss:0.1270 ||Epoch_E_Loss:0.1511
# timer:  0.4283 sec.
# -------------
# Epoch 1441/1500
# -------------
# （train）
# -------------
# epoch 1441 || Epoch_D_Loss:0.0947 ||Epoch_G_Loss:0.1404 ||Epoch_E_Loss:0.1492
# timer:  0.4307 sec.
# -------------
# Epoch 1442/1500
# -------------
# （train）
# -------------
# epoch 1442 || Epoch_D_Loss:0.0899 ||Epoch_G_Loss:0.1458 ||Epoch_E_Loss:0.1540
# timer:  0.4287 sec.
# -------------
# Epoch 1443/1500
# -------------
# （train）
# -------------
# epoch 1443 || Epoch_D_Loss:0.0880 ||Epoch_G_Loss:0.1491 ||Epoch_E_Loss:0.1615
# timer:  0.4298 sec.
# -------------
# Epoch 1444/1500
# -------------
# （train）
# -------------
# epoch 1444 || Epoch_D_Loss:0.0789 ||Epoch_G_Loss:0.1625 ||Epoch_E_Loss:0.1676
# timer:  0.4307 sec.
# -------------
# Epoch 1445/1500
# -------------
# （train）
# -------------
# epoch 1445 || Epoch_D_Loss:0.0915 ||Epoch_G_Loss:0.1564 ||Epoch_E_Loss:0.1560
# timer:  0.4301 sec.
# -------------
# Epoch 1446/1500
# -------------
# （train）
# -------------
# epoch 1446 || Epoch_D_Loss:0.1031 ||Epoch_G_Loss:0.1416 ||Epoch_E_Loss:0.1445
# timer:  0.4295 sec.
# -------------
# Epoch 1447/1500
# -------------
# （train）
# -------------
# epoch 1447 || Epoch_D_Loss:0.1060 ||Epoch_G_Loss:0.1250 ||Epoch_E_Loss:0.1414
# timer:  0.4303 sec.
# -------------
# Epoch 1448/1500
# -------------
# （train）
# -------------
# epoch 1448 || Epoch_D_Loss:0.1000 ||Epoch_G_Loss:0.1472 ||Epoch_E_Loss:0.1479
# timer:  0.4295 sec.
# -------------
# Epoch 1449/1500
# -------------
# （train）
# -------------
# epoch 1449 || Epoch_D_Loss:0.0927 ||Epoch_G_Loss:0.1472 ||Epoch_E_Loss:0.1631
# timer:  0.4301 sec.
# -------------
# Epoch 1450/1500
# -------------
# （train）
# -------------
# epoch 1450 || Epoch_D_Loss:0.0884 ||Epoch_G_Loss:0.1564 ||Epoch_E_Loss:0.1657
# timer:  0.4290 sec.
# -------------
# Epoch 1451/1500
# -------------
# （train）
# -------------
# epoch 1451 || Epoch_D_Loss:0.0952 ||Epoch_G_Loss:0.1430 ||Epoch_E_Loss:0.1593
# timer:  0.4296 sec.
# -------------
# Epoch 1452/1500
# -------------
# （train）
# -------------
# epoch 1452 || Epoch_D_Loss:0.1083 ||Epoch_G_Loss:0.1631 ||Epoch_E_Loss:0.1363
# timer:  0.4303 sec.
# -------------
# Epoch 1453/1500
# -------------
# （train）
# -------------
# epoch 1453 || Epoch_D_Loss:0.1071 ||Epoch_G_Loss:0.1347 ||Epoch_E_Loss:0.1570
# timer:  0.4294 sec.
# -------------
# Epoch 1454/1500
# -------------
# （train）
# -------------
# epoch 1454 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.1581 ||Epoch_E_Loss:0.1486
# timer:  0.4311 sec.
# -------------
# Epoch 1455/1500
# -------------
# （train）
# -------------
# epoch 1455 || Epoch_D_Loss:0.0789 ||Epoch_G_Loss:0.1655 ||Epoch_E_Loss:0.1640
# timer:  0.4299 sec.
# -------------
# Epoch 1456/1500
# -------------
# （train）
# -------------
# epoch 1456 || Epoch_D_Loss:0.0808 ||Epoch_G_Loss:0.1712 ||Epoch_E_Loss:0.1601
# timer:  0.4288 sec.
# -------------
# Epoch 1457/1500
# -------------
# （train）
# -------------
# epoch 1457 || Epoch_D_Loss:0.0864 ||Epoch_G_Loss:0.1531 ||Epoch_E_Loss:0.1633
# timer:  0.4303 sec.
# -------------
# Epoch 1458/1500
# -------------
# （train）
# -------------
# epoch 1458 || Epoch_D_Loss:0.1002 ||Epoch_G_Loss:0.1545 ||Epoch_E_Loss:0.1453
# timer:  0.4256 sec.
# -------------
# Epoch 1459/1500
# -------------
# （train）
# -------------
# epoch 1459 || Epoch_D_Loss:0.1010 ||Epoch_G_Loss:0.1371 ||Epoch_E_Loss:0.1463
# timer:  0.4259 sec.
# -------------
# Epoch 1460/1500
# -------------
# （train）
# -------------
# epoch 1460 || Epoch_D_Loss:0.1061 ||Epoch_G_Loss:0.1444 ||Epoch_E_Loss:0.1366
# timer:  0.4255 sec.
# -------------
# Epoch 1461/1500
# -------------
# （train）
# -------------
# epoch 1461 || Epoch_D_Loss:0.0977 ||Epoch_G_Loss:0.1366 ||Epoch_E_Loss:0.1562
# timer:  0.4269 sec.
# -------------
# Epoch 1462/1500
# -------------
# （train）
# -------------
# epoch 1462 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1671 ||Epoch_E_Loss:0.1499
# timer:  0.4266 sec.
# -------------
# Epoch 1463/1500
# -------------
# （train）
# -------------
# epoch 1463 || Epoch_D_Loss:0.0845 ||Epoch_G_Loss:0.1573 ||Epoch_E_Loss:0.1570
# timer:  0.4289 sec.
# -------------
# Epoch 1464/1500
# -------------
# （train）
# -------------
# epoch 1464 || Epoch_D_Loss:0.0912 ||Epoch_G_Loss:0.1462 ||Epoch_E_Loss:0.1743
# timer:  0.4277 sec.
# -------------
# Epoch 1465/1500
# -------------
# （train）
# -------------
# epoch 1465 || Epoch_D_Loss:0.0944 ||Epoch_G_Loss:0.1667 ||Epoch_E_Loss:0.1589
# timer:  0.4292 sec.
# -------------
# Epoch 1466/1500
# -------------
# （train）
# -------------
# epoch 1466 || Epoch_D_Loss:0.0894 ||Epoch_G_Loss:0.1528 ||Epoch_E_Loss:0.1614
# timer:  0.4272 sec.
# -------------
# Epoch 1467/1500
# -------------
# （train）
# -------------
# epoch 1467 || Epoch_D_Loss:0.0973 ||Epoch_G_Loss:0.1555 ||Epoch_E_Loss:0.1521
# timer:  0.4283 sec.
# -------------
# Epoch 1468/1500
# -------------
# （train）
# -------------
# epoch 1468 || Epoch_D_Loss:0.1088 ||Epoch_G_Loss:0.1507 ||Epoch_E_Loss:0.1433
# timer:  0.4272 sec.
# -------------
# Epoch 1469/1500
# -------------
# （train）
# -------------
# epoch 1469 || Epoch_D_Loss:0.1068 ||Epoch_G_Loss:0.1246 ||Epoch_E_Loss:0.1428
# timer:  0.4277 sec.
# -------------
# Epoch 1470/1500
# -------------
# （train）
# -------------
# epoch 1470 || Epoch_D_Loss:0.0985 ||Epoch_G_Loss:0.1429 ||Epoch_E_Loss:0.1472
# timer:  0.4299 sec.
# -------------
# Epoch 1471/1500
# -------------
# （train）
# -------------
# epoch 1471 || Epoch_D_Loss:0.0935 ||Epoch_G_Loss:0.1354 ||Epoch_E_Loss:0.1715
# timer:  0.4303 sec.
# -------------
# Epoch 1472/1500
# -------------
# （train）
# -------------
# epoch 1472 || Epoch_D_Loss:0.0964 ||Epoch_G_Loss:0.1599 ||Epoch_E_Loss:0.1512
# timer:  0.4306 sec.
# -------------
# Epoch 1473/1500
# -------------
# （train）
# -------------
# epoch 1473 || Epoch_D_Loss:0.0880 ||Epoch_G_Loss:0.1439 ||Epoch_E_Loss:0.1632
# timer:  0.4294 sec.
# -------------
# Epoch 1474/1500
# -------------
# （train）
# -------------
# epoch 1474 || Epoch_D_Loss:0.1009 ||Epoch_G_Loss:0.1446 ||Epoch_E_Loss:0.1479
# timer:  0.4295 sec.
# -------------
# Epoch 1475/1500
# -------------
# （train）
# -------------
# epoch 1475 || Epoch_D_Loss:0.1060 ||Epoch_G_Loss:0.1449 ||Epoch_E_Loss:0.1420
# timer:  0.4307 sec.
# -------------
# Epoch 1476/1500
# -------------
# （train）
# -------------
# epoch 1476 || Epoch_D_Loss:0.0976 ||Epoch_G_Loss:0.1489 ||Epoch_E_Loss:0.1533
# timer:  0.4314 sec.
# -------------
# Epoch 1477/1500
# -------------
# （train）
# -------------
# epoch 1477 || Epoch_D_Loss:0.0923 ||Epoch_G_Loss:0.1552 ||Epoch_E_Loss:0.1485
# timer:  0.4287 sec.
# -------------
# Epoch 1478/1500
# -------------
# （train）
# -------------
# epoch 1478 || Epoch_D_Loss:0.0939 ||Epoch_G_Loss:0.1335 ||Epoch_E_Loss:0.1603
# timer:  0.4299 sec.
# -------------
# Epoch 1479/1500
# -------------
# （train）
# -------------
# epoch 1479 || Epoch_D_Loss:0.1041 ||Epoch_G_Loss:0.1545 ||Epoch_E_Loss:0.1458
# timer:  0.4287 sec.
# -------------
# Epoch 1480/1500
# -------------
# （train）
# -------------
# epoch 1480 || Epoch_D_Loss:0.0927 ||Epoch_G_Loss:0.1404 ||Epoch_E_Loss:0.1560
# timer:  0.4290 sec.
# -------------
# Epoch 1481/1500
# -------------
# （train）
# -------------
# epoch 1481 || Epoch_D_Loss:0.0942 ||Epoch_G_Loss:0.1501 ||Epoch_E_Loss:0.1519
# timer:  0.4307 sec.
# -------------
# Epoch 1482/1500
# -------------
# （train）
# -------------
# epoch 1482 || Epoch_D_Loss:0.0964 ||Epoch_G_Loss:0.1441 ||Epoch_E_Loss:0.1578
# timer:  0.4306 sec.
# -------------
# Epoch 1483/1500
# -------------
# （train）
# -------------
# epoch 1483 || Epoch_D_Loss:0.0948 ||Epoch_G_Loss:0.1552 ||Epoch_E_Loss:0.1644
# timer:  0.4294 sec.
# -------------
# Epoch 1484/1500
# -------------
# （train）
# -------------
# epoch 1484 || Epoch_D_Loss:0.1019 ||Epoch_G_Loss:0.1681 ||Epoch_E_Loss:0.1619
# timer:  0.4282 sec.
# -------------
# Epoch 1485/1500
# -------------
# （train）
# -------------
# epoch 1485 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1648 ||Epoch_E_Loss:0.1644
# timer:  0.4261 sec.
# -------------
# Epoch 1486/1500
# -------------
# （train）
# -------------
# epoch 1486 || Epoch_D_Loss:0.0855 ||Epoch_G_Loss:0.1714 ||Epoch_E_Loss:0.1595
# timer:  0.4261 sec.
# -------------
# Epoch 1487/1500
# -------------
# （train）
# -------------
# epoch 1487 || Epoch_D_Loss:0.0972 ||Epoch_G_Loss:0.1559 ||Epoch_E_Loss:0.1617
# timer:  0.4250 sec.
# -------------
# Epoch 1488/1500
# -------------
# （train）
# -------------
# epoch 1488 || Epoch_D_Loss:0.0919 ||Epoch_G_Loss:0.1351 ||Epoch_E_Loss:0.1565
# timer:  0.4261 sec.
# -------------
# Epoch 1489/1500
# -------------
# （train）
# -------------
# epoch 1489 || Epoch_D_Loss:0.1018 ||Epoch_G_Loss:0.1542 ||Epoch_E_Loss:0.1446
# timer:  0.4257 sec.
# -------------
# Epoch 1490/1500
# -------------
# （train）
# -------------
# epoch 1490 || Epoch_D_Loss:0.0998 ||Epoch_G_Loss:0.1464 ||Epoch_E_Loss:0.1381
# timer:  0.4247 sec.
# -------------
# Epoch 1491/1500
# -------------
# （train）
# -------------
# epoch 1491 || Epoch_D_Loss:0.1093 ||Epoch_G_Loss:0.1383 ||Epoch_E_Loss:0.1459
# timer:  0.4267 sec.
# -------------
# Epoch 1492/1500
# -------------
# （train）
# -------------
# epoch 1492 || Epoch_D_Loss:0.0994 ||Epoch_G_Loss:0.1283 ||Epoch_E_Loss:0.1495
# timer:  0.4258 sec.
# -------------
# Epoch 1493/1500
# -------------
# （train）
# -------------
# epoch 1493 || Epoch_D_Loss:0.0978 ||Epoch_G_Loss:0.1550 ||Epoch_E_Loss:0.1526
# timer:  0.4263 sec.
# -------------
# Epoch 1494/1500
# -------------
# （train）
# -------------
# epoch 1494 || Epoch_D_Loss:0.0859 ||Epoch_G_Loss:0.1787 ||Epoch_E_Loss:0.1557
# timer:  0.4303 sec.
# -------------
# Epoch 1495/1500
# -------------
# （train）
# -------------
# epoch 1495 || Epoch_D_Loss:0.0842 ||Epoch_G_Loss:0.1615 ||Epoch_E_Loss:0.1619
# timer:  0.4281 sec.
# -------------
# Epoch 1496/1500
# -------------
# （train）
# -------------
# epoch 1496 || Epoch_D_Loss:0.0781 ||Epoch_G_Loss:0.1606 ||Epoch_E_Loss:0.1768
# timer:  0.4303 sec.
# -------------
# Epoch 1497/1500
# -------------
# （train）
# -------------
# epoch 1497 || Epoch_D_Loss:0.0821 ||Epoch_G_Loss:0.1702 ||Epoch_E_Loss:0.1636
# timer:  0.4324 sec.
# -------------
# Epoch 1498/1500
# -------------
# （train）
# -------------
# epoch 1498 || Epoch_D_Loss:0.0837 ||Epoch_G_Loss:0.1539 ||Epoch_E_Loss:0.1779
# timer:  0.4316 sec.
# -------------
# Epoch 1499/1500
# -------------
# （train）
# -------------
# epoch 1499 || Epoch_D_Loss:0.0969 ||Epoch_G_Loss:0.1605 ||Epoch_E_Loss:0.1654
# timer:  0.4294 sec.
# 総イタレーション回数: 10501

# %%
# 生成画像と訓練データを可視化する
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イタレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %%
# 教師データの画像をエンコードしてzにしてから、Gで生成
z_out_real = E_update(imges.to(device))
imges_reconstract = G_update(z_out_real)
d_out_real = D_update(imges_reconstract, z_out_real)

# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(imges_reconstract[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# # テスト画像で異常検知する

# %%
# テスト用のDataLoaderの作成


def make_test_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(5):
        img_path = "./data/test_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


# ファイルリストを作成
test_img_list = make_test_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=True)

# %%
# テストデータの確認
batch_iterator = iter(test_dataloader)  # イタレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
def Anomaly_score(x, fake_img, z_out_real, D, Lambda=0.1):

    # テスト画像xと生成画像fake_imgのピクセルレベルの差の絶対値を求めて、ミニバッチごとに和を求める
    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    # テスト画像xと生成画像fake_imgを識別器Dに入力し、特徴量マップを取り出す

    _, x_feature = D(x, z_out_real)
    _, G_feature = D(fake_img, z_out_real)

    # テスト画像xと生成画像fake_imgの特徴量マップの差の絶対値を求めて、ミニバッチごとに和を求める
    discrimination_loss = torch.abs(x_feature-G_feature)
    discrimination_loss = discrimination_loss.view(
        discrimination_loss.size()[0], -1)
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    # ミニバッチごとに2種類の損失を足し算する
    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss

    # ミニバッチ全部の損失を求める
    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %%
# 異常検知したい画像
x = imges[0:5]
x = x.to(device)

# 教師データの画像をエンコードしてzにしてから、Gで生成
z_out_real = E_update(imges.to(device))
imges_reconstract = G_update(z_out_real)

# 損失を求める
loss, loss_each, residual_loss_each = Anomaly_score(
    x, imges_reconstract, z_out_real, D_update, Lambda=0.1)

# 損失の計算。トータルの損失
loss_each = loss_each.cpu().detach().numpy()
print(np.round(loss_each, 0))

# 損失の計算。画像レベルのresidual loss
residual_loss_each = residual_loss_each.cpu().detach().numpy()
print(np.round(residual_loss_each, 0))

# 画像を可視化
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    #plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')
    plt.imshow(imges_reconstract[i][0].cpu().detach().numpy(), 'gray')
# Out:
# [195. 267. 239. 158. 278.]
# [207. 292. 256. 170. 305.]

# %% [markdown]
# 以上
