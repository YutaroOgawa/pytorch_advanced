# %% [markdown]
# # 2.7 学習と検証の実施
#
# - 本ファイルでは、SSDの学習と検証の実施を行います。手元のマシンで動作を確認後、AWSのGPUマシンで計算します。
# - p2.xlargeで約6時間かかります。

# %% [markdown]
# # 学習目標
#
# 1.	SSDの学習を実装できるようになる

# %% [markdown]
# # 事前準備
#
# - AWS EC2 のGPUインスタンスを使用します
# - フォルダ「utils」のssd_model.pyをします

# %%
# パッケージのimport
import cv2
import numpy as np
import os.path as osp
import time
import random
import pandas as pd

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim

# %%
# 乱数のシードを設定
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)
# Out:
# 使用デバイス： cuda:0

# %% [markdown]
# # DatasetとDataLoaderを作成する

# %%
from utils.ssd_model import make_datapath_list, VOCDataset, DataTransform, Anno_xml2list, od_collate_fn


# ファイルパスのリストを取得
rootpath = "./data/VOCdevkit/VOC2012/"
train_img_list, train_anno_list, val_img_list, val_anno_list = make_datapath_list(
    rootpath)

# Datasetを作成
voc_classes = ['aeroplane', 'bicycle', 'bird', 'boat',
               'bottle', 'bus', 'car', 'cat', 'chair',
               'cow', 'diningtable', 'dog', 'horse',
               'motorbike', 'person', 'pottedplant',
               'sheep', 'sofa', 'train', 'tvmonitor']
color_mean = (104, 117, 123)  # (BGR)の色の平均値
input_size = 300  # 画像のinputサイズを300×300にする

train_dataset = VOCDataset(train_img_list, train_anno_list, phase="train", transform=DataTransform(
    input_size, color_mean), transform_anno=Anno_xml2list(voc_classes))

val_dataset = VOCDataset(val_img_list, val_anno_list, phase="val", transform=DataTransform(
    input_size, color_mean), transform_anno=Anno_xml2list(voc_classes))


# DataLoaderを作成する
batch_size = 32  # 32

train_dataloader = data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, collate_fn=od_collate_fn)

val_dataloader = data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False, collate_fn=od_collate_fn)

# 辞書オブジェクトにまとめる
dataloaders_dict = {"train": train_dataloader, "val": val_dataloader}

# %% [markdown]
# # ネットワークモデルの作成する

# %%
from utils.ssd_model import SSD

# SSD300の設定
ssd_cfg = {
    'num_classes': 21,  # 背景クラスを含めた合計クラス数
    'input_size': 300,  # 画像の入力サイズ
    'bbox_aspect_num': [4, 6, 6, 6, 4, 4],  # 出力するDBoxのアスペクト比の種類
    'feature_maps': [38, 19, 10, 5, 3, 1],  # 各sourceの画像サイズ
    'steps': [8, 16, 32, 64, 100, 300],  # DBOXの大きさを決める
    'min_sizes': [30, 60, 111, 162, 213, 264],  # DBOXの大きさを決める
    'max_sizes': [60, 111, 162, 213, 264, 315],  # DBOXの大きさを決める
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
}

# SSDネットワークモデル
net = SSD(phase="train", cfg=ssd_cfg)

# SSDの初期の重みを設定
# ssdのvgg部分に重みをロードする
vgg_weights = torch.load('./weights/vgg16_reducedfc.pth')
net.vgg.load_state_dict(vgg_weights)

# ssdのその他のネットワークの重みはHeの初期値で初期化


def weights_init(m):
    if isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight.data)
        if m.bias is not None:  # バイアス項がある場合
            nn.init.constant_(m.bias, 0.0)


# Heの初期値を適用
net.extras.apply(weights_init)
net.loc.apply(weights_init)
net.conf.apply(weights_init)

# GPUが使えるかを確認
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)

print('ネットワーク設定完了：学習済みの重みをロードしました')
# Out:
# 使用デバイス： cuda:0
# ネットワーク設定完了：学習済みの重みをロードしました

# %% [markdown]
# # 損失関数と最適化手法を定義する

# %%
from utils.ssd_model import MultiBoxLoss

# 損失関数の設定
criterion = MultiBoxLoss(jaccard_thresh=0.5, neg_pos=3, device=device)

# 最適化手法の設定
optimizer = optim.SGD(net.parameters(), lr=1e-3,
                      momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# # 学習・検証を実施する

# %%
# モデルを学習させる関数を作成


def train_model(net, dataloaders_dict, criterion, optimizer, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # ネットワークをGPUへ
    net.to(device)

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # イタレーションカウンタをセット
    iteration = 1
    epoch_train_loss = 0.0  # epochの損失和
    epoch_val_loss = 0.0  # epochの損失和
    logs = []

    # epochのループ
    for epoch in range(num_epochs+1):

        # 開始時刻を保存
        t_epoch_start = time.time()
        t_iter_start = time.time()

        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')

        # epochごとの訓練と検証のループ
        for phase in ['train', 'val']:
            if phase == 'train':
                net.train()  # モデルを訓練モードに
                print('（train）')
            else:
                if((epoch+1) % 10 == 0):
                    net.eval()   # モデルを検証モードに
                    print('-------------')
                    print('（val）')
                else:
                    # 検証は10回に1回だけ行う
                    continue

            # データローダーからminibatchずつ取り出すループ
            for images, targets in dataloaders_dict[phase]:

                # GPUが使えるならGPUにデータを送る
                images = images.to(device)
                targets = [ann.to(device)
                           for ann in targets]  # リストの各要素のテンソルをGPUへ

                # optimizerを初期化
                optimizer.zero_grad()

                # 順伝搬（forward）計算
                with torch.set_grad_enabled(phase == 'train'):
                    # 順伝搬（forward）計算
                    outputs = net(images)

                    # 損失の計算
                    loss_l, loss_c = criterion(outputs, targets)
                    loss = loss_l + loss_c

                    # 訓練時はバックプロパゲーション
                    if phase == 'train':
                        loss.backward()  # 勾配の計算

                        # 勾配が大きくなりすぎると計算が不安定になるので、clipで最大でも勾配2.0に留める
                        nn.utils.clip_grad_value_(
                            net.parameters(), clip_value=2.0)

                        optimizer.step()  # パラメータ更新

                        if (iteration % 10 == 0):  # 10iterに1度、lossを表示
                            t_iter_finish = time.time()
                            duration = t_iter_finish - t_iter_start
                            print('イタレーション {} || Loss: {:.4f} || 10iter: {:.4f} sec.'.format(
                                iteration, loss.item(), duration))
                            t_iter_start = time.time()

                        epoch_train_loss += loss.item()
                        iteration += 1

                    # 検証時
                    else:
                        epoch_val_loss += loss.item()

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_TRAIN_Loss:{:.4f} ||Epoch_VAL_Loss:{:.4f}'.format(
            epoch+1, epoch_train_loss, epoch_val_loss))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

        # ログを保存
        log_epoch = {'epoch': epoch+1,
                     'train_loss': epoch_train_loss, 'val_loss': epoch_val_loss}
        logs.append(log_epoch)
        df = pd.DataFrame(logs)
        df.to_csv("log_output.csv")

        epoch_train_loss = 0.0  # epochの損失和
        epoch_val_loss = 0.0  # epochの損失和

        # ネットワークを保存する
        if ((epoch+1) % 10 == 0):
            torch.save(net.state_dict(), 'weights/ssd300_' +
                       str(epoch+1) + '.pth')

# %%
# 学習・検証を実行する
num_epochs= 50  
train_model(net, dataloaders_dict, criterion, optimizer, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 1/50
# -------------
# （train）
# イタレーション 10 || Loss: 16.7855 || 10iter: 56.8422 sec.
# イタレーション 20 || Loss: 12.0645 || 10iter: 25.4445 sec.
# イタレーション 30 || Loss: 12.1115 || 10iter: 25.7550 sec.
# イタレーション 40 || Loss: 9.4758 || 10iter: 25.9485 sec.
# イタレーション 50 || Loss: 8.8132 || 10iter: 25.5214 sec.
# イタレーション 60 || Loss: 8.6267 || 10iter: 25.6975 sec.
# イタレーション 70 || Loss: 8.9257 || 10iter: 25.3736 sec.
# イタレーション 80 || Loss: 8.8706 || 10iter: 26.0773 sec.
# イタレーション 90 || Loss: 8.5930 || 10iter: 25.6935 sec.
# イタレーション 100 || Loss: 8.2677 || 10iter: 25.0656 sec.
# イタレーション 110 || Loss: 8.4029 || 10iter: 26.9894 sec.
# イタレーション 120 || Loss: 8.0918 || 10iter: 26.3040 sec.
# イタレーション 130 || Loss: 7.8098 || 10iter: 25.5423 sec.
# イタレーション 140 || Loss: 7.8255 || 10iter: 25.1672 sec.
# イタレーション 150 || Loss: 7.9216 || 10iter: 24.8809 sec.
# イタレーション 160 || Loss: 7.7873 || 10iter: 25.6822 sec.
# イタレーション 170 || Loss: 7.4295 || 10iter: 25.4814 sec.
# -------------
# epoch 1 || Epoch_TRAIN_Loss:1687.4547 ||Epoch_VAL_Loss:0.0000
# timer:  538.0991 sec.
# -------------
# Epoch 2/50
# -------------
# （train）
# イタレーション 180 || Loss: 7.5651 || 10iter: 1.3065 sec.
# イタレーション 190 || Loss: 6.8902 || 10iter: 25.8381 sec.
# イタレーション 200 || Loss: 7.3317 || 10iter: 25.4160 sec.
# イタレーション 210 || Loss: 7.3568 || 10iter: 25.7559 sec.
# イタレーション 220 || Loss: 6.6821 || 10iter: 25.2102 sec.
# イタレーション 230 || Loss: 7.1105 || 10iter: 25.4016 sec.
# イタレーション 240 || Loss: 7.3369 || 10iter: 25.9567 sec.
# イタレーション 250 || Loss: 7.0086 || 10iter: 25.1942 sec.
# イタレーション 260 || Loss: 7.0562 || 10iter: 25.7516 sec.
# イタレーション 270 || Loss: 7.2185 || 10iter: 25.3624 sec.
# イタレーション 280 || Loss: 7.2969 || 10iter: 25.8475 sec.
# イタレーション 1050 || Loss: 6.2129 || 10iter: 26.1796 sec.
# イタレーション 1060 || Loss: 6.3695 || 10iter: 25.4463 sec.
# イタレーション 1070 || Loss: 5.9543 || 10iter: 24.5329 sec.
# -------------
# epoch 6 || Epoch_TRAIN_Loss:1066.5892 ||Epoch_VAL_Loss:0.0000
# timer:  481.1934 sec.
# -------------
# Epoch 7/50
# -------------
# （train）
# イタレーション 1080 || Loss: 6.0067 || 10iter: 14.5181 sec.
# イタレーション 1090 || Loss: 5.8405 || 10iter: 26.0609 sec.
# イタレーション 1100 || Loss: 5.4987 || 10iter: 25.2395 sec.
# イタレーション 1110 || Loss: 5.9184 || 10iter: 26.0259 sec.
# イタレーション 1120 || Loss: 5.5377 || 10iter: 25.3571 sec.
# イタレーション 1130 || Loss: 5.5845 || 10iter: 24.9353 sec.
# イタレーション 1140 || Loss: 5.5712 || 10iter: 24.8574 sec.
# イタレーション 1150 || Loss: 5.8602 || 10iter: 25.3984 sec.
# イタレーション 1160 || Loss: 5.5486 || 10iter: 25.4688 sec.
# イタレーション 1170 || Loss: 5.7510 || 10iter: 24.9603 sec.
# イタレーション 1180 || Loss: 6.0118 || 10iter: 24.7909 sec.
# イタレーション 1190 || Loss: 5.9172 || 10iter: 25.0360 sec.
# イタレーション 1200 || Loss: 5.7470 || 10iter: 25.5684 sec.
# イタレーション 1210 || Loss: 5.7053 || 10iter: 25.5848 sec.
# イタレーション 1220 || Loss: 5.7620 || 10iter: 25.0223 sec.
# イタレーション 1230 || Loss: 5.5722 || 10iter: 24.9100 sec.
# イタレーション 1240 || Loss: 5.2146 || 10iter: 25.0930 sec.
# イタレーション 1250 || Loss: 5.4368 || 10iter: 25.5424 sec.
# -------------
# epoch 7 || Epoch_TRAIN_Loss:1030.9436 ||Epoch_VAL_Loss:0.0000
# timer:  476.6073 sec.
# -------------
# Epoch 8/50
# -------------
# （train）
# イタレーション 1260 || Loss: 5.6995 || 10iter: 17.7092 sec.
# イタレーション 1270 || Loss: 5.5656 || 10iter: 25.9326 sec.
# イタレーション 1280 || Loss: 5.6197 || 10iter: 25.9981 sec.
# イタレーション 1290 || Loss: 5.5240 || 10iter: 24.8657 sec.
# イタレーション 1300 || Loss: 5.3339 || 10iter: 25.5232 sec.
# イタレーション 1310 || Loss: 5.4990 || 10iter: 25.3171 sec.
# イタレーション 1320 || Loss: 6.0814 || 10iter: 25.4371 sec.
# イタレーション 1330 || Loss: 5.5288 || 10iter: 25.4768 sec.
# イタレーション 1340 || Loss: 5.5722 || 10iter: 25.7155 sec.
# イタレーション 1350 || Loss: 5.4884 || 10iter: 26.2980 sec.
# イタレーション 1360 || Loss: 5.5854 || 10iter: 25.2966 sec.
# イタレーション 1370 || Loss: 5.5336 || 10iter: 25.6530 sec.
# イタレーション 1380 || Loss: 5.9921 || 10iter: 26.7026 sec.
# イタレーション 1390 || Loss: 5.5947 || 10iter: 25.7720 sec.
# イタレーション 1400 || Loss: 5.6044 || 10iter: 25.1158 sec.
# イタレーション 1410 || Loss: 5.8772 || 10iter: 25.8379 sec.
# epoch 12 || Epoch_TRAIN_Loss:908.0911 ||Epoch_VAL_Loss:0.0000
# timer:  487.6057 sec.
# -------------
# Epoch 13/50
# -------------
# （train）
# イタレーション 2150 || Loss: 5.0551 || 10iter: 4.2512 sec.
# イタレーション 2160 || Loss: 4.6748 || 10iter: 24.6507 sec.
# イタレーション 2170 || Loss: 4.9902 || 10iter: 26.1705 sec.
# イタレーション 2180 || Loss: 5.0022 || 10iter: 25.4866 sec.
# イタレーション 2190 || Loss: 4.9080 || 10iter: 26.1657 sec.
# イタレーション 2200 || Loss: 5.2034 || 10iter: 25.7796 sec.
# イタレーション 2210 || Loss: 4.5981 || 10iter: 25.6448 sec.
# イタレーション 2220 || Loss: 5.4704 || 10iter: 25.5275 sec.
# イタレーション 2230 || Loss: 4.9508 || 10iter: 25.0806 sec.
# イタレーション 2240 || Loss: 4.8946 || 10iter: 25.0273 sec.
# イタレーション 2250 || Loss: 5.1456 || 10iter: 24.9111 sec.
# イタレーション 2260 || Loss: 4.8677 || 10iter: 26.6312 sec.
# イタレーション 2270 || Loss: 4.8573 || 10iter: 25.7118 sec.
# イタレーション 2280 || Loss: 4.8643 || 10iter: 24.7257 sec.
# イタレーション 2290 || Loss: 4.7464 || 10iter: 25.4863 sec.
# イタレーション 2300 || Loss: 5.8304 || 10iter: 24.4341 sec.
# イタレーション 2310 || Loss: 5.1844 || 10iter: 25.0234 sec.
# イタレーション 2320 || Loss: 5.1180 || 10iter: 24.9475 sec.
# -------------
# epoch 13 || Epoch_TRAIN_Loss:890.3210 ||Epoch_VAL_Loss:0.0000
# timer:  479.2493 sec.
# -------------
# Epoch 14/50
# -------------
# （train）
# イタレーション 2330 || Loss: 4.8775 || 10iter: 6.5728 sec.
# イタレーション 2340 || Loss: 5.2306 || 10iter: 26.5212 sec.
# イタレーション 2350 || Loss: 4.9813 || 10iter: 25.7277 sec.
# イタレーション 2360 || Loss: 5.2802 || 10iter: 25.7829 sec.
# イタレーション 2370 || Loss: 5.3444 || 10iter: 25.2634 sec.
# イタレーション 2380 || Loss: 5.3526 || 10iter: 25.2686 sec.
# イタレーション 2390 || Loss: 4.9172 || 10iter: 25.3549 sec.
# イタレーション 2400 || Loss: 5.0635 || 10iter: 24.6242 sec.
# イタレーション 2410 || Loss: 5.4600 || 10iter: 25.6533 sec.
# イタレーション 2420 || Loss: 5.6112 || 10iter: 25.9053 sec.
# イタレーション 2430 || Loss: 5.0336 || 10iter: 26.1505 sec.
# イタレーション 2440 || Loss: 4.9966 || 10iter: 25.1251 sec.
# イタレーション 2450 || Loss: 4.8599 || 10iter: 25.6645 sec.
# イタレーション 2460 || Loss: 4.5197 || 10iter: 25.2583 sec.
# イタレーション 2470 || Loss: 4.7922 || 10iter: 26.5922 sec.
# イタレーション 2480 || Loss: 5.0189 || 10iter: 25.2489 sec.
# イタレーション 2490 || Loss: 4.9195 || 10iter: 26.1865 sec.
# イタレーション 2500 || Loss: 5.1812 || 10iter: 26.3895 sec.
# -------------
# epoch 14 || Epoch_TRAIN_Loss:883.3398 ||Epoch_VAL_Loss:0.0000
# timer:  483.5491 sec.
# イタレーション 4350 || Loss: 4.5996 || 10iter: 24.9237 sec.
# イタレーション 4360 || Loss: 4.6076 || 10iter: 25.6203 sec.
# イタレーション 4370 || Loss: 3.8410 || 10iter: 25.5038 sec.
# イタレーション 4380 || Loss: 4.2327 || 10iter: 25.9086 sec.
# イタレーション 4390 || Loss: 4.1507 || 10iter: 25.1772 sec.
# イタレーション 4400 || Loss: 4.0412 || 10iter: 26.1088 sec.
# イタレーション 4410 || Loss: 4.0432 || 10iter: 24.7067 sec.
# イタレーション 4420 || Loss: 3.8670 || 10iter: 24.9614 sec.
# イタレーション 4430 || Loss: 4.2324 || 10iter: 25.9451 sec.
# イタレーション 4440 || Loss: 4.4722 || 10iter: 24.4073 sec.
# イタレーション 4450 || Loss: 4.0907 || 10iter: 25.1554 sec.
# イタレーション 4460 || Loss: 4.2290 || 10iter: 25.2704 sec.
# イタレーション 4470 || Loss: 4.2906 || 10iter: 25.2485 sec.
# -------------
# epoch 25 || Epoch_TRAIN_Loss:751.8500 ||Epoch_VAL_Loss:0.0000
# timer:  481.5973 sec.
# -------------
# Epoch 26/50
# -------------
# （train）
# イタレーション 4480 || Loss: 4.3322 || 10iter: 12.2289 sec.
# イタレーション 4490 || Loss: 4.0984 || 10iter: 25.8674 sec.
# イタレーション 4500 || Loss: 4.0011 || 10iter: 25.1360 sec.
# イタレーション 4510 || Loss: 3.6484 || 10iter: 26.5284 sec.
# イタレーション 4520 || Loss: 4.2470 || 10iter: 25.7086 sec.
# イタレーション 4530 || Loss: 3.7569 || 10iter: 26.0231 sec.
# イタレーション 4540 || Loss: 3.9339 || 10iter: 25.3822 sec.
# イタレーション 4550 || Loss: 4.1380 || 10iter: 25.6571 sec.
# イタレーション 4560 || Loss: 4.6665 || 10iter: 26.0743 sec.
# イタレーション 4570 || Loss: 4.5414 || 10iter: 25.9068 sec.
# イタレーション 4580 || Loss: 4.2677 || 10iter: 26.3105 sec.
# イタレーション 4590 || Loss: 4.0930 || 10iter: 26.5461 sec.
# イタレーション 4600 || Loss: 4.0076 || 10iter: 25.6777 sec.
# イタレーション 4610 || Loss: 4.3916 || 10iter: 25.8866 sec.
# イタレーション 4620 || Loss: 4.1942 || 10iter: 25.9736 sec.
# イタレーション 4630 || Loss: 3.9242 || 10iter: 25.3277 sec.
# イタレーション 4640 || Loss: 4.1127 || 10iter: 25.6529 sec.
# イタレーション 4650 || Loss: 4.1000 || 10iter: 26.1499 sec.
# -------------
# epoch 26 || Epoch_TRAIN_Loss:741.1809 ||Epoch_VAL_Loss:0.0000
# timer:  487.6628 sec.
# -------------
# Epoch 27/50
# -------------
# （train）
# イタレーション 4660 || Loss: 4.2379 || 10iter: 14.4918 sec.
# イタレーション 4670 || Loss: 4.1463 || 10iter: 25.5900 sec.
# イタレーション 4680 || Loss: 4.2699 || 10iter: 25.3877 sec.
# イタレーション 4690 || Loss: 4.4369 || 10iter: 26.4513 sec.
# イタレーション 4700 || Loss: 3.7020 || 10iter: 25.6829 sec.
# イタレーション 4710 || Loss: 4.0361 || 10iter: 25.3003 sec.
# イタレーション 5830 || Loss: 3.6283 || 10iter: 25.4277 sec.
# イタレーション 5840 || Loss: 3.5607 || 10iter: 25.5790 sec.
# イタレーション 5850 || Loss: 4.0776 || 10iter: 25.0039 sec.
# イタレーション 5860 || Loss: 3.3055 || 10iter: 25.8127 sec.
# イタレーション 5870 || Loss: 4.1878 || 10iter: 25.5542 sec.
# イタレーション 5880 || Loss: 4.2932 || 10iter: 27.6290 sec.
# イタレーション 5890 || Loss: 4.0714 || 10iter: 25.1186 sec.
# イタレーション 5900 || Loss: 3.4161 || 10iter: 25.2770 sec.
# -------------
# epoch 33 || Epoch_TRAIN_Loss:693.4009 ||Epoch_VAL_Loss:0.0000
# timer:  480.7997 sec.
# -------------
# Epoch 34/50
# -------------
# （train）
# イタレーション 5910 || Loss: 3.8367 || 10iter: 6.5907 sec.
# イタレーション 5920 || Loss: 4.0382 || 10iter: 25.9424 sec.
# イタレーション 5930 || Loss: 3.9611 || 10iter: 25.5008 sec.
# イタレーション 5940 || Loss: 4.1431 || 10iter: 25.5673 sec.
# イタレーション 5950 || Loss: 4.2431 || 10iter: 25.1033 sec.
# イタレーション 5960 || Loss: 4.4188 || 10iter: 26.3791 sec.
# イタレーション 5970 || Loss: 3.4841 || 10iter: 25.7209 sec.
# イタレーション 5980 || Loss: 3.6496 || 10iter: 25.5483 sec.
# イタレーション 5990 || Loss: 3.7249 || 10iter: 25.4874 sec.
# イタレーション 6000 || Loss: 4.2017 || 10iter: 26.6424 sec.
# イタレーション 6010 || Loss: 3.7036 || 10iter: 25.3897 sec.
# イタレーション 6020 || Loss: 3.6767 || 10iter: 25.2418 sec.
# イタレーション 6030 || Loss: 3.8434 || 10iter: 25.9603 sec.
# イタレーション 6040 || Loss: 4.0597 || 10iter: 25.7029 sec.
# イタレーション 6050 || Loss: 3.8384 || 10iter: 26.0891 sec.
# イタレーション 6060 || Loss: 3.2572 || 10iter: 26.7287 sec.
# イタレーション 6070 || Loss: 3.9231 || 10iter: 26.0973 sec.
# イタレーション 6080 || Loss: 3.8802 || 10iter: 25.2925 sec.
# -------------
# epoch 34 || Epoch_TRAIN_Loss:684.7514 ||Epoch_VAL_Loss:0.0000
# timer:  486.5163 sec.
# -------------
# Epoch 35/50
# -------------
# （train）
# イタレーション 6090 || Loss: 4.0715 || 10iter: 9.4353 sec.
# イタレーション 6100 || Loss: 3.9383 || 10iter: 25.9653 sec.
# イタレーション 6110 || Loss: 4.0256 || 10iter: 24.7468 sec.
# イタレーション 6120 || Loss: 3.3937 || 10iter: 24.8958 sec.
# イタレーション 6130 || Loss: 3.4427 || 10iter: 24.9286 sec.
# イタレーション 6140 || Loss: 4.0697 || 10iter: 25.2123 sec.
# イタレーション 6150 || Loss: 4.1352 || 10iter: 25.2946 sec.
# イタレーション 6160 || Loss: 3.5554 || 10iter: 25.4001 sec.
# イタレーション 6170 || Loss: 3.7216 || 10iter: 25.0250 sec.
# イタレーション 6180 || Loss: 3.6392 || 10iter: 24.9534 sec.
# イタレーション 6190 || Loss: 3.9823 || 10iter: 25.1108 sec.
# イタレーション 6570 || Loss: 3.7309 || 10iter: 25.2846 sec.
# イタレーション 6580 || Loss: 3.7638 || 10iter: 24.9994 sec.
# イタレーション 6590 || Loss: 3.8319 || 10iter: 26.7380 sec.
# イタレーション 6600 || Loss: 4.1201 || 10iter: 25.4983 sec.
# イタレーション 6610 || Loss: 3.7250 || 10iter: 26.7261 sec.
# イタレーション 6620 || Loss: 3.5058 || 10iter: 26.1455 sec.
# -------------
# epoch 37 || Epoch_TRAIN_Loss:668.4700 ||Epoch_VAL_Loss:0.0000
# timer:  483.6720 sec.
# -------------
# Epoch 38/50
# -------------
# （train）
# イタレーション 6630 || Loss: 3.4040 || 10iter: 17.9922 sec.
# イタレーション 6640 || Loss: 3.3653 || 10iter: 26.3742 sec.
# イタレーション 6650 || Loss: 2.9603 || 10iter: 25.8658 sec.
# イタレーション 6660 || Loss: 3.2034 || 10iter: 25.9983 sec.
# イタレーション 6670 || Loss: 3.5887 || 10iter: 25.3965 sec.
# イタレーション 6680 || Loss: 3.8774 || 10iter: 25.9697 sec.
# イタレーション 6690 || Loss: 4.1112 || 10iter: 25.5485 sec.
# イタレーション 6700 || Loss: 4.0144 || 10iter: 25.6895 sec.
# イタレーション 6710 || Loss: 4.1072 || 10iter: 26.0590 sec.
# イタレーション 6720 || Loss: 3.5675 || 10iter: 25.7996 sec.
# イタレーション 6730 || Loss: 3.9669 || 10iter: 25.0799 sec.
# イタレーション 6740 || Loss: 3.5270 || 10iter: 26.7334 sec.
# イタレーション 6750 || Loss: 3.6086 || 10iter: 25.6359 sec.
# イタレーション 6760 || Loss: 3.7182 || 10iter: 25.8616 sec.
# イタレーション 6770 || Loss: 3.3856 || 10iter: 25.1818 sec.
# イタレーション 6780 || Loss: 3.6041 || 10iter: 25.8577 sec.
# イタレーション 6790 || Loss: 3.9333 || 10iter: 25.9851 sec.
# イタレーション 6800 || Loss: 3.4793 || 10iter: 25.9723 sec.
# -------------
# epoch 38 || Epoch_TRAIN_Loss:666.6890 ||Epoch_VAL_Loss:0.0000
# timer:  488.0061 sec.
# -------------
# Epoch 39/50
# -------------
# （train）
# イタレーション 6810 || Loss: 4.1479 || 10iter: 20.2294 sec.
# イタレーション 6820 || Loss: 3.5176 || 10iter: 25.9758 sec.
# イタレーション 6830 || Loss: 3.5798 || 10iter: 25.1273 sec.
# イタレーション 6840 || Loss: 3.6164 || 10iter: 25.7199 sec.
# イタレーション 6850 || Loss: 3.8225 || 10iter: 25.8477 sec.
# イタレーション 6860 || Loss: 3.6669 || 10iter: 25.5076 sec.
# イタレーション 6870 || Loss: 3.5214 || 10iter: 26.1864 sec.
# イタレーション 6880 || Loss: 3.8865 || 10iter: 25.4400 sec.
# イタレーション 6890 || Loss: 3.7801 || 10iter: 25.8262 sec.
# イタレーション 6900 || Loss: 3.5785 || 10iter: 24.9307 sec.
# イタレーション 6910 || Loss: 3.3999 || 10iter: 25.4419 sec.
# イタレーション 6920 || Loss: 3.4718 || 10iter: 26.0494 sec.
# イタレーション 6930 || Loss: 3.1448 || 10iter: 25.6372 sec.
# イタレーション 8040 || Loss: 3.4922 || 10iter: 25.1368 sec.
# イタレーション 8050 || Loss: 3.3749 || 10iter: 25.1288 sec.
# -------------
# epoch 45 || Epoch_TRAIN_Loss:638.4875 ||Epoch_VAL_Loss:0.0000
# timer:  476.2390 sec.
# -------------
# Epoch 46/50
# -------------
# （train）
# イタレーション 8060 || Loss: 3.4103 || 10iter: 12.1389 sec.
# イタレーション 8070 || Loss: 3.4709 || 10iter: 26.3351 sec.
# イタレーション 8080 || Loss: 3.1628 || 10iter: 26.2816 sec.
# イタレーション 8090 || Loss: 3.4439 || 10iter: 25.2164 sec.
# イタレーション 8100 || Loss: 3.5322 || 10iter: 26.5406 sec.
# イタレーション 8110 || Loss: 3.9425 || 10iter: 25.9930 sec.
# イタレーション 8120 || Loss: 3.5517 || 10iter: 26.0529 sec.
# イタレーション 8130 || Loss: 2.8094 || 10iter: 26.1619 sec.
# イタレーション 8140 || Loss: 3.7260 || 10iter: 25.6256 sec.
# イタレーション 8150 || Loss: 3.7778 || 10iter: 25.9643 sec.
# イタレーション 8160 || Loss: 3.5408 || 10iter: 26.8926 sec.
# イタレーション 8170 || Loss: 3.9817 || 10iter: 26.5341 sec.
# イタレーション 8180 || Loss: 3.5449 || 10iter: 25.6559 sec.
# イタレーション 8190 || Loss: 3.5353 || 10iter: 25.4507 sec.
# イタレーション 8200 || Loss: 3.4015 || 10iter: 25.0588 sec.
# イタレーション 8210 || Loss: 3.2838 || 10iter: 25.8151 sec.
# イタレーション 8220 || Loss: 3.3467 || 10iter: 25.5586 sec.
# イタレーション 8230 || Loss: 3.0808 || 10iter: 25.3809 sec.
# -------------
# epoch 46 || Epoch_TRAIN_Loss:632.5500 ||Epoch_VAL_Loss:0.0000
# timer:  488.2781 sec.
# -------------
# Epoch 47/50
# -------------
# （train）
# イタレーション 8240 || Loss: 3.2784 || 10iter: 15.1426 sec.
# イタレーション 8250 || Loss: 2.8617 || 10iter: 24.9630 sec.
# イタレーション 8260 || Loss: 3.8384 || 10iter: 26.1853 sec.
# イタレーション 8270 || Loss: 3.4088 || 10iter: 25.4262 sec.
# イタレーション 8280 || Loss: 3.3051 || 10iter: 24.9266 sec.
# イタレーション 8290 || Loss: 3.7623 || 10iter: 24.9944 sec.
# イタレーション 8300 || Loss: 3.0000 || 10iter: 25.4858 sec.
# イタレーション 8310 || Loss: 3.1129 || 10iter: 25.4085 sec.
# イタレーション 8320 || Loss: 3.2715 || 10iter: 25.2981 sec.
# イタレーション 8330 || Loss: 3.7458 || 10iter: 24.4800 sec.
# イタレーション 8340 || Loss: 4.1444 || 10iter: 25.9169 sec.
# イタレーション 8350 || Loss: 3.8439 || 10iter: 24.8977 sec.
# イタレーション 8360 || Loss: 4.1370 || 10iter: 25.4318 sec.
# イタレーション 8370 || Loss: 3.8058 || 10iter: 25.6553 sec.
# イタレーション 8380 || Loss: 3.3342 || 10iter: 24.4895 sec.
# イタレーション 8390 || Loss: 3.3641 || 10iter: 25.0854 sec.
# イタレーション 8400 || Loss: 3.1424 || 10iter: 24.7200 sec.
# epoch 49 || Epoch_TRAIN_Loss:620.1318 ||Epoch_VAL_Loss:0.0000
# timer:  480.1561 sec.
# -------------
# Epoch 50/50
# -------------
# （train）
# イタレーション 8780 || Loss: 3.5539 || 10iter: 23.1204 sec.
# イタレーション 8790 || Loss: 3.2547 || 10iter: 25.6060 sec.
# イタレーション 8800 || Loss: 3.5000 || 10iter: 25.3092 sec.
# イタレーション 8810 || Loss: 3.4836 || 10iter: 25.6224 sec.
# イタレーション 8820 || Loss: 3.8416 || 10iter: 25.8729 sec.
# イタレーション 8830 || Loss: 3.9125 || 10iter: 25.5144 sec.
# イタレーション 8840 || Loss: 3.3382 || 10iter: 25.3509 sec.
# イタレーション 8850 || Loss: 3.1177 || 10iter: 25.0462 sec.
# イタレーション 8860 || Loss: 3.2494 || 10iter: 25.3302 sec.
# イタレーション 8870 || Loss: 3.7811 || 10iter: 25.7272 sec.
# イタレーション 8880 || Loss: 3.4595 || 10iter: 25.5764 sec.
# イタレーション 8890 || Loss: 3.2165 || 10iter: 25.6601 sec.
# イタレーション 8900 || Loss: 3.1571 || 10iter: 26.3231 sec.
# イタレーション 8910 || Loss: 3.7994 || 10iter: 24.5153 sec.
# イタレーション 8920 || Loss: 3.7687 || 10iter: 25.5323 sec.
# イタレーション 8930 || Loss: 3.3761 || 10iter: 25.7080 sec.
# イタレーション 8940 || Loss: 3.6020 || 10iter: 24.7761 sec.
# イタレーション 8950 || Loss: 3.5303 || 10iter: 25.6017 sec.
# -------------
# （val）
# -------------
# epoch 50 || Epoch_TRAIN_Loss:612.8540 ||Epoch_VAL_Loss:684.6773
# timer:  658.7737 sec.
# -------------
# Epoch 51/50
# -------------
# （train）
# イタレーション 8960 || Loss: 3.4696 || 10iter: 25.6868 sec.
# イタレーション 8970 || Loss: 3.4748 || 10iter: 25.1775 sec.
# イタレーション 8980 || Loss: 2.7930 || 10iter: 25.5690 sec.
# イタレーション 8990 || Loss: 3.3649 || 10iter: 25.1353 sec.
# イタレーション 9000 || Loss: 3.5118 || 10iter: 25.0671 sec.
# イタレーション 9010 || Loss: 3.7106 || 10iter: 24.7717 sec.
# イタレーション 9020 || Loss: 3.0947 || 10iter: 24.8395 sec.
# イタレーション 9030 || Loss: 3.2805 || 10iter: 25.7808 sec.
# イタレーション 9040 || Loss: 3.5248 || 10iter: 25.1933 sec.
# イタレーション 9050 || Loss: 3.4516 || 10iter: 25.1496 sec.
# イタレーション 9060 || Loss: 3.7732 || 10iter: 26.4764 sec.
# イタレーション 9070 || Loss: 3.2760 || 10iter: 25.1172 sec.
# イタレーション 9080 || Loss: 3.5033 || 10iter: 25.9056 sec.
# イタレーション 9090 || Loss: 3.7659 || 10iter: 25.4882 sec.
# イタレーション 9100 || Loss: 3.2009 || 10iter: 26.3528 sec.
# イタレーション 9110 || Loss: 3.2530 || 10iter: 25.7937 sec.
# イタレーション 9120 || Loss: 3.4065 || 10iter: 24.9048 sec.
# -------------
# epoch 51 || Epoch_TRAIN_Loss:618.2713 ||Epoch_VAL_Loss:0.0000
# timer:  478.2189 sec.

# %% [markdown]
# 以上
